# %% [markdown]
# # 0. What is visit history?
# * Ｇoal: 分析Chrome瀏覽器的使用歷程檔
# * What-is: 瀏覽器的log（即所謂的使用歷程檔）是什麼？上面有什麼資訊？請依照以以下連結的指示，開啟Chrome瀏覽器，找到右上角的工具選項，打開「記錄」。 http://www.googlechrometutorial.com/google-chrome-general-settings/Google-chrome-web-browser-history.html
# * Reference
#     * [How Google Chrome stores web history](http://lowmanio.co.uk/blog/entries/how-google-chrome-stores-web-history/)
#     * http://superuser.com/questions/627253/storing-browser-history-for-personal-analytics
#     * http://www.v2ex.com/t/60255
#
# #1. Copy chrome history out
# * 如何獲取Chrome History檔案？
# * 「access chrome history data」，之後應可找到下列網址http://stackoverflow.com/questions/2562092/how-to-access-google-chrome-browser-history-programmatically-on-local-machine
# 解釋】從上面鏈結可獲知Chrome History以sqlite資料庫的檔案形態放在使用者個人電腦端（並非在雲端）
#
# ## Windows
# * 如果是Windows的話是放在「C:\Documents and Settings\Local Settings\Application Data\Google\Chrome\User Data\Default」檔名為History。
# * 該檔案可能是隱藏檔，所以你必須自「資料夾選項」中開啟可看見隱藏檔的選項（以下資訊參考http://www.chromium.org/user-experience/user-data-directory）。
# * __Win8__:  C:\Documents and Settings\Local Settings\Application Data\Google\Chrome\User Data\Default
# * __Win 7__: C:\Users\[USERNAME]\AppData\Local\Google\Chrome\User Data\Default
# * __WinXP__: C:\Documents and Settings\[USERNAME]\Local Settings\Application Data\Google\Chrome\User Data\Default
#
# ##  Mac
# * 若使用Mac電腦的話，History檔可能會放置在以下兩個位址：
#     * /Library（資源庫）/Application Support/Google/Chrome/Default/History
#     * /Users/[Your name]/Library（資源庫）/Application Support/Google/Chrome/Default/History
# * Mac的History檔為隱藏檔，需要用以下的方法取消隱藏
#     * 如果該檔案被隱藏無法搜尋的話，請在spotlight搜尋terminor，會開啟如下視窗（方法來源：view hidden folders on your mac using terminal０）
#         * 輸入defaults write com.apple.finder AppleShowAllFiles TRUE
#         * 輸入killall Finder即可找到該資料夾
#         * 之後請再輸入defaults write com.apple.finder AppleShowAllFiles FALSE
#         * 再輸入killall Finder即可恢復原狀。
#     * <font color = red>或者用這方法：打開Finder後，按住Option，點選上方「前往」中的「前往資料夾」，然後直接貼上上述兩個網址之一，注意要把（資源庫）拿掉，並且把你的使用者名稱貼上。例如：rawdata/Users/jirlong/Library/Application Support/Google/Chrome/Default/History</font>

# %% [markdown]
# #2. Browse the History file
# * Chrome history是sqlite檔而無法被一般的程式（例如NotePad）開啟。 那麼，何謂sqlite檔案？他和一般資料庫檔案（例如.mdb）有何不同？
# * 無論是Firefox或Chrome history均以sqlite的資料庫格式儲存成為一個檔案，所以現在需要用一個sqlite browser來開啟所下載的history檔。
# * 請上網搜尋"sqlite reader mac"或"sqlite reader windows"（Mac或Windows視你所用的系統而定，關鍵字reader可改為browser），下載並安裝。http://sourceforge.net/projects/sqlitebrowser/
# * 下載該工具並且打開你所下載的History檔案。觀查History的內容，並告訴我裡面記錄了哪些資料，又以何種形式來記錄？
#
# ##2.1 Brief introduction to chrome history
# * 安裝完畢後用其打開你所下載的History檔案，應可見到如下的界面。共分為三個主要部分，分別為：
#     * Database Structure：用以觀看整個資料庫的綱要或欄位
#     * Browse Data：用以瀏覽資料庫內存的資料<--我們最主要要看這個資料。
#     * Execute SQL：允許你用這個界面操作SQL指令以查詢
#     * <img src="Figures/sqlbrowser.png" style="width: 50%; height: 50%"/>
# * 點選Browse Data後應可見到以下界面，開啟Table的下拉式選單，一共可發現以下資料庫的資料表：
#     * meta
#     * downloads：下載的檔案
#     * download_url_chains
#     * urls：曾經拜訪過的urls的ID與網址對照表
#     * visits：主要的瀏覽歷程資料表，其中需要以ID查詢瀏覽時所拜訪的urls（查詢前項urls資料表）
#     * visit_source
#     * keyword_search_terms：查詢關鍵字
#     * segments
#     * segment_usage
# * 請開啟urls資料表並開啟「檔案>export」的選項將該資料表另存為csv（comma-separated value）檔。再開啟visits資料表，並用上述的方法另存為csv檔。只要儲存為csv檔後，不僅易於程式處理，而且匯入Excel也會十分方便。
#
# ##2.2 Tables of chrome history
# * History Table – urls. urls資料表主要記錄了你所曾經拜訪過的所有的網頁網址，每一筆記錄就是一筆唯一的網址，如果你曾經拜訪過某網址兩次，他也只會有一筆記錄，它記錄了以下欄位：
#     * id：該網址的id，用以索引
#     * url：該網址本身
#     * title：該網頁的title（可能會從缺）
#     * visit_count：使用者在這段時間中一共拜訪該網頁幾次
#     * typed_count
#     * last_visit_time：使用者最後一次拜訪該網頁的時間（你在看網頁的時候，他有時候會告訴你「您最近一次拜訪時間為...」就是看這個欄位）
#     * hidden：是否為隱藏的記錄
#     * favicon_id
#
# ## 2.3 SQL queries to retrieve data
# * 通常類似的SQLite Database Browser都會提供輸入資料庫查詢命令的功能，點選Execute SQL後即可看到輸入SQL查詢命令的欄位。例如我們希望查詢urls這個表中，究竟有哪些網址，並且按照該網址的拜訪次數來排序的話，可以輸入「select visit_count, url from urls order by visit_count」測試之。
#     * 查詢一：我希望從urls這個表格中把visit_count和url這兩個欄位的資料給選擇出來，並且按照url這個欄位進行排序。
#             select visit_count, url from urls order by url
#     * 查詢二：我希望從visits這個表格中把所有的visit給找出來，並且找出url, visit_time(拜訪時間), from_visit(從哪個URL跳過來), transition(怎麼跳過來), visit_duration(拜訪多久)。且所有的結果照著id來排序。
#             select url,visit_time, from_visit, transition, visit_duration from visits order by id;
#     * 查詢三：我希望整合visits和urls這兩個表的資料，依據是visits表的url等於urls表的id。同時找出visits表的拜訪時間、拜訪時間長，以及這個urls表的url（因為visits表的url存的是一個編碼）。
#             SELECT visits.id, visits.visit_time, visits.visit_duration, urls.url FROM visits INNER JOIN urls ON visits.url=urls.id;
# * 如果我今天想要查詢資料表visits中的拜訪時間、拜訪的持續時間、拜訪的網址那要怎麼做？此時你若打開資料表visits會發現拜訪網址欄位為url，其內容是一個編號，這個id必須參考對照資料表urls的id和url欄位。因此必須要輸入以下指令：
#         SELECT visits.id, visits.visit_time, visits.visit_duration, urls.url
#         FROM visits
#         INNER JOIN urls
#         ON visits.url=urls.id;

# %% [markdown]
# #3. Read Chrome history by python
# ##3.1  import sqlite3
# * 為了讀SQLite檔案，必須import sqlite3函式庫，該函式庫為Python安裝時所內建的函式庫，只需import不用另外安裝。
# * 把下載下來的History檔案放在同資料中如下圖即可讀取。之後參見https://docs.python.org/2/library/sqlite3.html，
# * 該文件的內容說明了sqlite3這個函式庫可以讓使用者建立table、寫入資料並讀取資料庫。

# %%
import sqlite3
import urlparse
import datetime

# %% [markdown]
# ##3.2 Connect to history sqlite file

# %%
# conn=sqlite3.connect("History")
conn=sqlite3.connect("../../log_ChromeHistory/History")
cu = conn.cursor()

# %% [markdown]
# ##3.3 執行sql查詢（Send a sql query to cu）
# * w3school SQL Introduction http://www.w3schools.com/sql/sql_intro.asp
# * An example: 從（from）urls這個表中，依序選出（select）visit_count與url這兩個欄位，並且照url排序（order by）
#         select visit_count, url from urls order by url;

# %%
sql = "select visit_count, url from urls order by visit_count;"
cu.execute(sql)
res=cu.fetchall()
# print res[:10]
print "[COMMAND(num_of_res=%d)]:%s"%(len(res), sql)
for r in sorted(res, reverse=True)[:10]:
    print "%s\t%s"%(r[0], r[1])
# Out:
# [COMMAND(num_of_res=14659)]:select visit_count, url from urls order by visit_count;
# 874	http://mail.google.com/
# 654	https://www.facebook.com/
# 500	http://www.facebook.com/
# 429	https://mail.google.com/
# 407	https://mail.google.com/mail/
# 403	https://mail.google.com/mail/u/0/
# 292	https://mail.google.com/mail/u/0/#label/%5Bntnulib%5D
# 270	http://comic.sfacg.com/
# 255	http://www.yahoo.com.tw/
# 219	http://tw.yahoo.com/

# %% [markdown]
# ## 3.4 網址的處理 Combine urls according to their hosts
# * 注意看下面query後的結果，顯然如果是mail.google.com開頭的網址，應該都算進mail.google.com就好，不要有那麼多個不一樣的網址。
#         874	http://mail.google.com/
#         654	https://www.facebook.com/
#         500	http://www.facebook.com/
#         429	https://mail.google.com/
#         407	https://mail.google.com/mail/
#         403	https://mail.google.com/mail/u/0/
#         292	https://mail.google.com/mail/u/0/#label/%5Bntnulib%5D
#         270	http://comic.sfacg.com/
#         255	http://www.yahoo.com.tw/
#         219	http://tw.yahoo.com/
# * 所以我現在希望能夠把前面開頭是mail.google.com的都算成是拜訪同一個網址，並且累計總共拜訪幾次。
# * 相當於要建一個dictionary 把網址前段mapping到出現次數的加總。
# * 而現在的問題是要怎麼把網址斷開？
#
# ### 3.4.1 string operations
# * 各位是否還記得我們曾經看過一個程式如下，他用sentences.split()把所有的字通通斷開了。
#     1. 把所有的奇怪的字元刪除，包含
#         >!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#             sentences = sentences.translate(None, string.punctuation)
#     2. 把所有的字轉小寫
#             sentences = sentences.lower()
#     3. 把要輸入的字串依照空白斷開
#             wordlist = sentences.split()
#     4. 用for-each讀取wordlist中的每一個word，看他出現幾次。

# %%
import string
sentences = 'All men have stars, but they are not the same things for different people. For some, who are travelers, the stars are guides. For others they are no more than little lights in the sky. For others, who are scholars, they are problems... But all these stars are silent. You-You alone will have stars as no one else has them... In one of the stars I shall be living. In one of them I shall be laughing. And so it will be as if all the stars will be laughing when you look at the sky at night..You, only you, will have stars that can laugh! And when your sorrow is comforted (time soothes all sorrows) you will be content that you have known me... You will always be my friend. You will want to laugh with me. And you will sometimes open your window, so, for that pleasure... It will be as if, in place of the stars, I had given you a great number of little bells that knew how to laugh'
sentences = sentences.translate(None, string.punctuation)
sentences = sentences.lower()

## Introduce the split() function

# %% [markdown]
# ### 3.4.2 split the url by "/"

# %%
urlstr = 'https://mail.google.com/mail/u/0/#label/%5Bntnulib%5D'
# print urlstr.split('/')
urlseq = urlstr.split('/')
print urlseq[2]
# Out:
# mail.google.com

# %% [markdown]
# ###3.4.3 combine urls according to the 1st segment of url
# * 下面我們將把/當成切割字串的工具，好獲得網址。
# * 但是你將會遇到一個問題，就是這些資料裡面有兩個資料並非你預期中的資料，這兩個資料是因為使用者從網頁上按了「寄送信件」的按鈕後，系統自動把網頁導引到寄送信件的頁面所產生。
#         mailto:jirlong@ntnu.edu.tw?bcc=96501054@nccu.edu.tw
#         mailto:jackho@ntnu.edu.tw
# * 總之會出錯，你有三種方法處理他
#     1. 知道有這種錯誤，所以排除他！（有mailto在item[0]的通通拿掉），但問題是你怎麼知道有他？
#     2. 偵測如果split()後的結果，長度大於2，代表至少有三個，那我才處理。
#     3. 用try和except。
# * EXPECTED RESULTS
#         ERROR ITEM:mailto:jackho@ntnu.edu.tw
#         ERROR ITEM:mailto:jirlong@ntnu.edu.tw?bcc=96501054@nccu.edu.tw
#         [4674, u'mail.google.com']
#         [3166, u'comic.sfacg.com']
#         [3076, u'www.google.com']
#         [1731, u'www.facebook.com']
#         [1295, u'www.youtube.com']
#         [907, u'moodle.ntnu.edu.tw']
#         [883, u'www.google.com.tw']
#         [764, u'tw.news.yahoo.com']
#         [570, u'coldpic.sfacg.com']
#         [551, u'docs.google.com']

# %%
## combine urls according to the 1st segment of url
url_dict = {}
for item in res:
    urlseg = item[1].split('/')
    url_dict.setdefault(urlseg[2], 0)
    url_dict[urlseg[2]] += item[0]
## But you will encounter an unexpected data entry such as "mailto:jirlong@ntnu.edu.tw?bcc=96501054@nccu.edu.tw"

## swap the column for next step sorting (STORED TO A NEW res_list)
res_list = []

## print the sorted result
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-634a6d69d8d1> in <module>()
#       3 for item in res:
#       4     urlseg = item[1].split('/')
# ----> 5     url_dict.setdefault(urlseg[2], 0)
#       6     url_dict[urlseg[2]] += item[0]
#       7 ## But you will encounter an unexpected data entry such as "mailto:jirlong@ntnu.edu.tw?bcc=96501054@nccu.edu.tw"
#
# IndexError: list index out of range

# %% [markdown]
# ##3.5 Convert the block of database query to a function
# * 因為下面這兩行常常會用到，不如把它轉成一個「功能性的區塊」，就是function。
#         cu.execute(sql)
#         res=cu.fetchall()
# * y = func(a, b) = sqrt(axa + bxb)
#     * y稱為傳回值 return value
#     * a, b為傳入函式的值。
#     * func(a, b) = sqrt(axa + bxb) 稱為func函式的定義。
# * 函式的定義大致如下
#         ## Define a function
#         def function_name(invalue1, invalue2, invalue3):
#             result1, result2 = 0, 0
#             ## Add some processing here
#
#             return result1, result2
# * 目前希望的是能夠用下面的方式進行查詢，程式碼會變得比較簡單。
#         res = query("select url,visit_time, from_visit, transition, visit_duration from visits order by id ;")
#         res = query("SELECT visits.id, visits.visit_time, visits.visit_duration, urls.url FROM visits INNER JOIN urls ON visits.url=urls.id;")
# * 而目前有的送出查詢的程式碼如下
#         cu.execute(sql)
#         res=cu.fetchall()
#         print "[COMMAND(num_of_res=%d)]:%s"%(len(res), sql)

# %%
## TODO: Define a query function here

# %% [markdown]
# ##3.6 Query the visits table by the following sql
# * 用sql browser觀察visits這個表，發現表中的url欄位儲存的不是真正的網址，而只有儲存網址的id。
# * 而這個id，要對應到urls這個資料表的id欄位，才可以查出他所對應到的網址是什麼（urls中的url欄位）。所以要寫一道sql的查詢指令，"INNER JOIN"兩個表（你在這邊不需要知道INNER JOIN是什麼，只要你知道下面這道指令的意思就好了）。
#         SELECT urls.url, visits.visit_time, visits.visit_duration, visits.id, visits.from_visit, visits.transition, visits.segment_id, urls.id FROM visits INNER JOIN urls ON visits.url=urls.id;
# * 如果你想更瞭解SQL指令，可以參閱w3school上的說明。w3school SQL Introduction http://www.w3schools.com/sql/sql_intro.asp。

# %%
## TODO: Modify the following code by use of query function
cu.execute("SELECT urls.url, visits.visit_time, visits.visit_duration FROM visits INNER JOIN urls ON visits.url=urls.id;")
res=cu.fetchall()

## TODO: PRINT OUT THE QUERY
# Out:
# 13024375992405427 4763264 https://www.google.com.tw/search?q=ma&oq=ma&aqs=chrome..69i57j69i65j0j5j0.361j0&sourceid=chrome&ie=UTF-8
# 13024375995839026 0 http://mail.google.com/
# 13024375995839026 0 https://mail.google.com/
# 13024375996831155 0 https://mail.google.com/mail/
# 13024375996831155 0 https://accounts.google.com/ServiceLogin?service=mail&passive=true&rm=false&continue=https://mail.google.com/mail/&ss=1&scc=1&ltmpl=default&ltmplcache=2&emr=1

# %% [markdown]
# ##3.7 Convert timestamp to readable string
# * 針對這樣的結果，看似有一些手續要處理，第一個，取出網址的前段，第二個，轉換時間成為python讀得懂的格式，不然根本看不懂。
# * 這個看似整數的時間是網路處理時間的方法，為了讓python讀得懂這串數字是什麼，可以使用人家已經寫好的時間函式，把整數timestamp轉換為python datetime的方法可查詢"convert timestamp to datetime python"
#     * 獲得以下結果http://stackoverflow.com/questions/9744775/how-to-convert-integer-timestamp-to-python-datetime
#             >>> import datetime
#             >>> your_timestamp = 1331856000000
#             >>> date = datetime.datetime.fromtimestamp(your_timestamp / 1e3)
# * 因為該整數是以microsecond來累計，所以要除以1000，標準的做法是除以1e3。
# * duration也要轉，

# %%
epoch_start = datetime.datetime(1601,1,1) + datetime.timedelta(hours = 8)
for r in res[:50]:
    # retrieve the first segment of url
    urlhost = urlparse.urlparse(r[0]).netloc
    # convert integer time stamp to datetime
#     print r[1]
    if r[2] != 0.0:
        dt = datetime.timedelta(microseconds = r[1]) 
        duration = datetime.timedelta(microseconds = r[2])
        print urlhost, epoch_start+dt, duration
# Out:
# www.google.com.tw 2013-09-23 10:13:12.405427 0:00:04.763264
# accounts.google.com 2013-09-23 10:13:23.875352 0:01:58.716769
# mail.google.com 2013-09-23 10:17:00.571372 0:00:01.930268
# www.google.com.tw 2013-09-23 10:25:28.395769 0:01:56.083688
# www.mapquest.com 2013-09-23 10:26:44.527680 0:00:38.473438
# mail.google.com 2013-09-23 10:30:14.557195 0:00:13.043616

# %% [markdown]
# ##3.8 getTime() convert timestamp to python datatime
# * EXPECTED OUTPUT
#         2013-09-23 10:13:12.405427 0:00:04.763264 https://www.google.com.tw/search?q=ma&oq=ma&aqs=chrome..69i57j69i65j0j5j0.361j0&sourceid=chrome&ie=UTF-8
#         2013-09-23 10:13:15.839026 0:00:00 http://mail.google.com/
#         2013-09-23 10:13:15.839026 0:00:00 https://mail.google.com/
#         2013-09-23 10:13:16.831155 0:00:00 https://mail.google.com/mail/
#         2013-09-23 10:13:16.831155 0:00:00 https://accounts.google.com/ServiceLogin?service=mail&passive=true&rm=false&continue=https://mail.google.com/mail/&ss=1&scc=1&ltmpl=default&ltmplcache=2&emr=1

# %%
## TODO: CONVERT THE PREVIOUS CODE TO A getTime() FUNCTION

# %%
for r in res[:40]:
#     if r[2] != 0.0:
    print getTime(r[1]), getTime(r[2], 'duration'), r[0]
# Out:
# 2013-09-23 10:13:12.405427 0:00:04.763264 https://www.google.com.tw/search?q=ma&oq=ma&aqs=chrome..69i57j69i65j0j5j0.361j0&sourceid=chrome&ie=UTF-8
# 2013-09-23 10:13:15.839026 0:00:00 http://mail.google.com/
# 2013-09-23 10:13:15.839026 0:00:00 https://mail.google.com/
# 2013-09-23 10:13:16.831155 0:00:00 https://mail.google.com/mail/
# 2013-09-23 10:13:16.831155 0:00:00 https://accounts.google.com/ServiceLogin?service=mail&passive=true&rm=false&continue=https://mail.google.com/mail/&ss=1&scc=1&ltmpl=default&ltmplcache=2&emr=1
# 2013-09-23 10:13:23.875352 0:01:58.716769 https://accounts.google.com/ServiceLoginAuth
# 2013-09-23 10:13:24.883494 0:00:00 https://mail.google.com/mail/?auth=DQAAAI4AAABJTOogR8FxLuQMyOErddFzSVGW7Pcy0-5CeBSqRnBuMkPyx4yP2cHh3DcJ0jpFFCF7QmlaFaDg_eZv3Bi1n55NpkAi7RWshhykAFJY8ZPKHzt6r61rBK0Kz6trK4-K1L4fWe46_giEAc737jfptqs0hi6PTSgpJcT1wfRPVl4wH_Zbar0ElmWKcLXN9H330Yk
# 2013-09-23 10:13:24.883494 0:00:00 https://mail.google.com/mail/u/0/?auth=DQAAAI4AAABJTOogR8FxLuQMyOErddFzSVGW7Pcy0-5CeBSqRnBuMkPyx4yP2cHh3DcJ0jpFFCF7QmlaFaDg_eZv3Bi1n55NpkAi7RWshhykAFJY8ZPKHzt6r61rBK0Kz6trK4-K1L4fWe46_giEAc737jfptqs0hi6PTSgpJcT1wfRPVl4wH_Zbar0ElmWKcLXN9H330Yk&shva=1
# 2013-09-23 10:13:24.883494 0:00:00 https://mail.google.com/mail/u/0/?shva=1
# 2013-09-23 10:13:26.908314 0:00:00 https://mail.google.com/mail/u/0/?shva=1#inbox
# 2013-09-23 10:13:31.287087 0:00:00 https://mail.google.com/mail/u/0/?shva=1#label/%5Bntnulib%5D
# 2013-09-23 10:13:34.254543 0:00:00 https://mail.google.com/mail/u/0/?shva=1#label/%5Bntnulib%5D/1414893bec324083
# 2013-09-23 10:13:42.387513 0:00:00 https://mail.google.com/mail/u/0/?shva=1#label/%5Bntnulib%5D
# 2013-09-23 10:13:43.689719 0:00:00 https://talkgadget.google.com/u/0/talkgadget/_/chat?client=sm&prop=gmail&nav=true&fid=gtn-roster-iframe-id&os=MacIntel&stime=1379902412330&xpc=%7B%22cn%22%3A%22z1nj5v%22%2C%22tp%22%3A1%2C%22ifrid%22%3A%22gtn-roster-iframe-id%22%2C%22pu%22%3A%22https%3A%2F%2Ftalkgadget.google.com%2Fu%2F0%2Ftalkgadget%2F_%2F%22%7D&ec=%5B%22ci%3Aec%22%2Ctrue%2Ctrue%2Cfalse%5D&pvt=AMP3uWZP1rjMpjI-SiA4UciCzFgv42i7opNPt-VkmjC0JGMetFmsXLOg7a-Jt_k--q_Q4axd1Hn-TUbSFH_qkeUIMF_Y69sJgA%3D%3D&href=https%3A%2F%2Fmail.google.com%2F_%2Fmail-static%2F_%2Fjs%2Fmain%2Fm_i%2Ct%2Cit%2Frt%3Dh%2Fver%3DChLH7arW7OU.en.%2Fsv%3D1%2Fam%3D!TYHFcgOpBkP0RMHS-QuYX8A6FJH69v_8LYhkoDTGeMJjj6vi6C7GnsXSyX1JhHsmRCr2x3Mf7A%2Fd%3D1%3Frel%3D1&pos=l&uiv=2&hl=en&hpc=true&hsm=true&hrc=true&pal=1&uqp=false&sl=false&hs=%5B%22h_hs%22%2Cnull%2Cnull%2C%5B2%2C2%5D%5D&moleh=380&mmoleh=36&two=https%3A%2F%2Fmail.google.com&host=1&zx=4kajfqtva8fo
# 2013-09-23 10:13:43.689719 0:00:00 https://talkgadget.google.com/u/0/talkgadget/_/chat?client=sm&prop=gmail&nav=true&fid=gtn-roster-iframe-id&os=MacIntel&stime=1379902412330&xpc=%7B%22cn%22%3A%22z1nj5v%22%2C%22tp%22%3A1%2C%22ifrid%22%3A%22gtn-roster-iframe-id%22%2C%22pu%22%3A%22https%3A%2F%2Ftalkgadget.google.com%2Fu%2F0%2Ftalkgadget%2F_%2F%22%7D&ec=%5B%22ci%3Aec%22%2Ctrue%2Ctrue%2Cfalse%5D&pvt=AMP3uWZP1rjMpjI-SiA4UciCzFgv42i7opNPt-VkmjC0JGMetFmsXLOg7a-Jt_k--q_Q4axd1Hn-TUbSFH_qkeUIMF_Y69sJgA%3D%3D&href=https%3A%2F%2Fmail.google.com%2F_%2Fmail-static%2F_%2Fjs%2Fmain%2Fm_i%2Ct%2Cit%2Frt%3Dh%2Fver%3DChLH7arW7OU.en.%2Fsv%3D1%2Fam%3D!TYHFcgOpBkP0RMHS-QuYX8A6FJH69v_8LYhkoDTGeMJjj6vi6C7GnsXSyX1JhHsmRCr2x3Mf7A%2Fd%3D1%3Frel%3D1&pos=l&uiv=2&hl=en&hpc=true&hsm=true&hrc=true&pal=1&uqp=false&sl=false&hs=%5B%22h_hs%22%2Cnull%2Cnull%2C%5B2%2C2%5D%5D&moleh=380&mmoleh=36&two=https%3A%2F%2Fmail.google.com&host=1&zx=4kajfqtva8fo&retry_module_load=1
# 2013-09-23 10:13:44.907833 0:00:00 https://mail.google.com/mail/u/0/?shva=1#inbox
# 2013-09-23 10:13:54.310997 0:00:00 https://mail.google.com/mail/u/0/?shva=1#inbox/1413facdb34fce5e
# 2013-09-23 10:14:14.229230 0:00:00 https://talkgadget.google.com/u/0/talkgadget/_/chat?client=sm&prop=gmail&nav=true&fid=gtn-roster-iframe-id&os=MacIntel&stime=1379902412330&xpc=%7B%22cn%22%3A%22z1nj5v%22%2C%22tp%22%3A1%2C%22ifrid%22%3A%22gtn-roster-iframe-id%22%2C%22pu%22%3A%22https%3A%2F%2Ftalkgadget.google.com%2Fu%2F0%2Ftalkgadget%2F_%2F%22%7D&ec=%5B%22ci%3Aec%22%2Ctrue%2Ctrue%2Cfalse%5D&pvt=AMP3uWZP1rjMpjI-SiA4UciCzFgv42i7opNPt-VkmjC0JGMetFmsXLOg7a-Jt_k--q_Q4axd1Hn-TUbSFH_qkeUIMF_Y69sJgA%3D%3D&href=https%3A%2F%2Fmail.google.com%2F_%2Fmail-static%2F_%2Fjs%2Fmain%2Fm_i%2Ct%2Cit%2Frt%3Dh%2Fver%3DChLH7arW7OU.en.%2Fsv%3D1%2Fam%3D!TYHFcgOpBkP0RMHS-QuYX8A6FJH69v_8LYhkoDTGeMJjj6vi6C7GnsXSyX1JhHsmRCr2x3Mf7A%2Fd%3D1%3Frel%3D1&pos=l&uiv=2&hl=en&hpc=true&hsm=true&hrc=true&pal=1&uqp=false&sl=false&hs=%5B%22h_hs%22%2Cnull%2Cnull%2C%5B2%2C2%5D%5D&moleh=380&mmoleh=36&two=https%3A%2F%2Fmail.google.com&host=1&zx=4kajfqtva8fo&retry_module_load=1
# 2013-09-23 10:14:14.229230 0:00:00 https://talkgadget.google.com/u/0/talkgadget/_/chat?client=sm&prop=gmail&nav=true&fid=gtn-roster-iframe-id&os=MacIntel&stime=1379902412330&xpc=%7B%22cn%22%3A%22z1nj5v%22%2C%22tp%22%3A1%2C%22ifrid%22%3A%22gtn-roster-iframe-id%22%2C%22pu%22%3A%22https%3A%2F%2Ftalkgadget.google.com%2Fu%2F0%2Ftalkgadget%2F_%2F%22%7D&ec=%5B%22ci%3Aec%22%2Ctrue%2Ctrue%2Cfalse%5D&pvt=AMP3uWZP1rjMpjI-SiA4UciCzFgv42i7opNPt-VkmjC0JGMetFmsXLOg7a-Jt_k--q_Q4axd1Hn-TUbSFH_qkeUIMF_Y69sJgA%3D%3D&href=https%3A%2F%2Fmail.google.com%2F_%2Fmail-static%2F_%2Fjs%2Fmain%2Fm_i%2Ct%2Cit%2Frt%3Dh%2Fver%3DChLH7arW7OU.en.%2Fsv%3D1%2Fam%3D!TYHFcgOpBkP0RMHS-QuYX8A6FJH69v_8LYhkoDTGeMJjj6vi6C7GnsXSyX1JhHsmRCr2x3Mf7A%2Fd%3D1%3Frel%3D1&pos=l&uiv=2&hl=en&hpc=true&hsm=true&hrc=true&pal=1&uqp=false&sl=false&hs=%5B%22h_hs%22%2Cnull%2Cnull%2C%5B2%2C2%5D%5D&moleh=380&mmoleh=36&two=https%3A%2F%2Fmail.google.com&host=1&zx=4kajfqtva8fo&retry_module_load=2
# 2013-09-23 10:14:26.857276 0:00:00 https://talkgadget.google.com/u/0/talkgadget/_/chat?client=sm&prop=gmail&nav=true&fid=gtn-roster-iframe-id&os=MacIntel&stime=1379902412330&xpc=%7B%22cn%22%3A%22z1nj5v%22%2C%22tp%22%3A1%2C%22ifrid%22%3A%22gtn-roster-iframe-id%22%2C%22pu%22%3A%22https%3A%2F%2Ftalkgadget.google.com%2Fu%2F0%2Ftalkgadget%2F_%2F%22%7D&ec=%5B%22ci%3Aec%22%2Ctrue%2Ctrue%2Cfalse%5D&pvt=AMP3uWZP1rjMpjI-SiA4UciCzFgv42i7opNPt-VkmjC0JGMetFmsXLOg7a-Jt_k--q_Q4axd1Hn-TUbSFH_qkeUIMF_Y69sJgA%3D%3D&href=https%3A%2F%2Fmail.google.com%2F_%2Fmail-static%2F_%2Fjs%2Fmain%2Fm_i%2Ct%2Cit%2Frt%3Dh%2Fver%3DChLH7arW7OU.en.%2Fsv%3D1%2Fam%3D!TYHFcgOpBkP0RMHS-QuYX8A6FJH69v_8LYhkoDTGeMJjj6vi6C7GnsXSyX1JhHsmRCr2x3Mf7A%2Fd%3D1%3Frel%3D1&pos=l&uiv=2&hl=en&hpc=true&hsm=true&hrc=true&pal=1&uqp=false&sl=false&hs=%5B%22h_hs%22%2Cnull%2Cnull%2C%5B2%2C2%5D%5D&moleh=380&mmoleh=36&two=https%3A%2F%2Fmail.google.com&host=1&zx=4kajfqtva8fo&retry_module_load=2
# 2013-09-23 10:14:26.857276 0:00:00 https://talkgadget.google.com/u/0/talkgadget/_/chat?client=sm&prop=gmail&nav=true&fid=gtn-roster-iframe-id&os=MacIntel&stime=1379902412330&xpc=%7B%22cn%22%3A%22z1nj5v%22%2C%22tp%22%3A1%2C%22ifrid%22%3A%22gtn-roster-iframe-id%22%2C%22pu%22%3A%22https%3A%2F%2Ftalkgadget.google.com%2Fu%2F0%2Ftalkgadget%2F_%2F%22%7D&ec=%5B%22ci%3Aec%22%2Ctrue%2Ctrue%2Cfalse%5D&pvt=AMP3uWZP1rjMpjI-SiA4UciCzFgv42i7opNPt-VkmjC0JGMetFmsXLOg7a-Jt_k--q_Q4axd1Hn-TUbSFH_qkeUIMF_Y69sJgA%3D%3D&href=https%3A%2F%2Fmail.google.com%2F_%2Fmail-static%2F_%2Fjs%2Fmain%2Fm_i%2Ct%2Cit%2Frt%3Dh%2Fver%3DChLH7arW7OU.en.%2Fsv%3D1%2Fam%3D!TYHFcgOpBkP0RMHS-QuYX8A6FJH69v_8LYhkoDTGeMJjj6vi6C7GnsXSyX1JhHsmRCr2x3Mf7A%2Fd%3D1%3Frel%3D1&pos=l&uiv=2&hl=en&hpc=true&hsm=true&hrc=true&uqp=false&sl=false&hs=%5B%22h_hs%22%2Cnull%2Cnull%2C%5B2%2C2%5D%5D&moleh=380&mmoleh=36&two=https%3A%2F%2Fmail.google.com&host=1&zx=0.6883780665230006&hb=1
# 2013-09-23 10:14:37.248631 0:00:00 https://talkgadget.google.com/u/0/talkgadget/_/chat?client=sm&prop=gmail&nav=true&fid=gtn-roster-iframe-id&os=MacIntel&stime=1379902412330&xpc=%7B%22cn%22%3A%22z1nj5v%22%2C%22tp%22%3A1%2C%22ifrid%22%3A%22gtn-roster-iframe-id%22%2C%22pu%22%3A%22https%3A%2F%2Ftalkgadget.google.com%2Fu%2F0%2Ftalkgadget%2F_%2F%22%7D&ec=%5B%22ci%3Aec%22%2Ctrue%2Ctrue%2Cfalse%5D&pvt=AMP3uWZP1rjMpjI-SiA4UciCzFgv42i7opNPt-VkmjC0JGMetFmsXLOg7a-Jt_k--q_Q4axd1Hn-TUbSFH_qkeUIMF_Y69sJgA%3D%3D&href=https%3A%2F%2Fmail.google.com%2F_%2Fmail-static%2F_%2Fjs%2Fmain%2Fm_i%2Ct%2Cit%2Frt%3Dh%2Fver%3DChLH7arW7OU.en.%2Fsv%3D1%2Fam%3D!TYHFcgOpBkP0RMHS-QuYX8A6FJH69v_8LYhkoDTGeMJjj6vi6C7GnsXSyX1JhHsmRCr2x3Mf7A%2Fd%3D1%3Frel%3D1&pos=l&uiv=2&hl=en&hpc=true&hsm=true&hrc=true&uqp=false&sl=false&hs=%5B%22h_hs%22%2Cnull%2Cnull%2C%5B2%2C2%5D%5D&moleh=380&mmoleh=36&two=https%3A%2F%2Fmail.google.com&host=1&zx=0.6883780665230006&hb=1
# 2013-09-23 10:14:37.248631 0:00:00 https://talkgadget.google.com/u/0/talkgadget/_/chat?client=sm&prop=gmail&nav=true&fid=gtn-roster-iframe-id&os=MacIntel&stime=1379902412330&xpc=%7B%22cn%22%3A%22z1nj5v%22%2C%22tp%22%3A1%2C%22ifrid%22%3A%22gtn-roster-iframe-id%22%2C%22pu%22%3A%22https%3A%2F%2Ftalkgadget.google.com%2Fu%2F0%2Ftalkgadget%2F_%2F%22%7D&ec=%5B%22ci%3Aec%22%2Ctrue%2Ctrue%2Cfalse%5D&pvt=AMP3uWZP1rjMpjI-SiA4UciCzFgv42i7opNPt-VkmjC0JGMetFmsXLOg7a-Jt_k--q_Q4axd1Hn-TUbSFH_qkeUIMF_Y69sJgA%3D%3D&href=https%3A%2F%2Fmail.google.com%2F_%2Fmail-static%2F_%2Fjs%2Fmain%2Fm_i%2Ct%2Cit%2Frt%3Dh%2Fver%3DChLH7arW7OU.en.%2Fsv%3D1%2Fam%3D!TYHFcgOpBkP0RMHS-QuYX8A6FJH69v_8LYhkoDTGeMJjj6vi6C7GnsXSyX1JhHsmRCr2x3Mf7A%2Fd%3D1%3Frel%3D1&pos=l&uiv=2&hl=en&hpc=true&hsm=true&hrc=true&uqp=false&sl=false&hs=%5B%22h_hs%22%2Cnull%2Cnull%2C%5B2%2C2%5D%5D&moleh=380&mmoleh=36&two=https%3A%2F%2Fmail.google.com&host=1&zx=0.6883780665230006&hb=1&retry_module_load=1
# 2013-09-23 10:15:07.779116 0:00:00 https://talkgadget.google.com/u/0/talkgadget/_/chat?client=sm&prop=gmail&nav=true&fid=gtn-roster-iframe-id&os=MacIntel&stime=1379902412330&xpc=%7B%22cn%22%3A%22z1nj5v%22%2C%22tp%22%3A1%2C%22ifrid%22%3A%22gtn-roster-iframe-id%22%2C%22pu%22%3A%22https%3A%2F%2Ftalkgadget.google.com%2Fu%2F0%2Ftalkgadget%2F_%2F%22%7D&ec=%5B%22ci%3Aec%22%2Ctrue%2Ctrue%2Cfalse%5D&pvt=AMP3uWZP1rjMpjI-SiA4UciCzFgv42i7opNPt-VkmjC0JGMetFmsXLOg7a-Jt_k--q_Q4axd1Hn-TUbSFH_qkeUIMF_Y69sJgA%3D%3D&href=https%3A%2F%2Fmail.google.com%2F_%2Fmail-static%2F_%2Fjs%2Fmain%2Fm_i%2Ct%2Cit%2Frt%3Dh%2Fver%3DChLH7arW7OU.en.%2Fsv%3D1%2Fam%3D!TYHFcgOpBkP0RMHS-QuYX8A6FJH69v_8LYhkoDTGeMJjj6vi6C7GnsXSyX1JhHsmRCr2x3Mf7A%2Fd%3D1%3Frel%3D1&pos=l&uiv=2&hl=en&hpc=true&hsm=true&hrc=true&uqp=false&sl=false&hs=%5B%22h_hs%22%2Cnull%2Cnull%2C%5B2%2C2%5D%5D&moleh=380&mmoleh=36&two=https%3A%2F%2Fmail.google.com&host=1&zx=0.6883780665230006&hb=1&retry_module_load=1
# 2013-09-23 10:15:07.779116 0:00:00 https://talkgadget.google.com/u/0/talkgadget/_/chat?client=sm&prop=gmail&nav=true&fid=gtn-roster-iframe-id&os=MacIntel&stime=1379902412330&xpc=%7B%22cn%22%3A%22z1nj5v%22%2C%22tp%22%3A1%2C%22ifrid%22%3A%22gtn-roster-iframe-id%22%2C%22pu%22%3A%22https%3A%2F%2Ftalkgadget.google.com%2Fu%2F0%2Ftalkgadget%2F_%2F%22%7D&ec=%5B%22ci%3Aec%22%2Ctrue%2Ctrue%2Cfalse%5D&pvt=AMP3uWZP1rjMpjI-SiA4UciCzFgv42i7opNPt-VkmjC0JGMetFmsXLOg7a-Jt_k--q_Q4axd1Hn-TUbSFH_qkeUIMF_Y69sJgA%3D%3D&href=https%3A%2F%2Fmail.google.com%2F_%2Fmail-static%2F_%2Fjs%2Fmain%2Fm_i%2Ct%2Cit%2Frt%3Dh%2Fver%3DChLH7arW7OU.en.%2Fsv%3D1%2Fam%3D!TYHFcgOpBkP0RMHS-QuYX8A6FJH69v_8LYhkoDTGeMJjj6vi6C7GnsXSyX1JhHsmRCr2x3Mf7A%2Fd%3D1%3Frel%3D1&pos=l&uiv=2&hl=en&hpc=true&hsm=true&hrc=true&uqp=false&sl=false&hs=%5B%22h_hs%22%2Cnull%2Cnull%2C%5B2%2C2%5D%5D&moleh=380&mmoleh=36&two=https%3A%2F%2Fmail.google.com&host=1&zx=0.6883780665230006&hb=1&retry_module_load=2
# 2013-09-23 10:15:22.592121 0:00:00 https://mail.google.com/mail/u/0/?shva=1#inbox/1413facdb34fce5e?compose=new
# 2013-09-23 10:15:39.403573 0:00:00 https://mail.google.com/mail/u/0/?shva=1#inbox/1413facdb34fce5e?compose=1414899c6149c162
# 2013-09-23 10:15:48.992754 0:00:00 https://mail.google.com/mail/u/0/?shva=1#inbox/1413facdb34fce5e?compose=1414899ed9d7a1c4
# 2013-09-23 10:15:53.032499 0:00:00 https://mail.google.com/mail/u/0/?shva=1#inbox/1413facdb34fce5e?compose=1414899fc79a6235
# 2013-09-23 10:16:02.620901 0:00:00 https://mail.google.com/mail/u/0/?shva=1#inbox/1413facdb34fce5e?compose=141489a20ab4f876
# 2013-09-23 10:16:07.567594 0:00:00 https://talkgadget.google.com/u/0/talkgadget/_/chat?client=sm&prop=gmail&nav=true&fid=gtn-roster-iframe-id&os=MacIntel&stime=1379902412330&xpc=%7B%22cn%22%3A%22z1nj5v%22%2C%22tp%22%3A1%2C%22ifrid%22%3A%22gtn-roster-iframe-id%22%2C%22pu%22%3A%22https%3A%2F%2Ftalkgadget.google.com%2Fu%2F0%2Ftalkgadget%2F_%2F%22%7D&ec=%5B%22ci%3Aec%22%2Ctrue%2Ctrue%2Cfalse%5D&pvt=AMP3uWZP1rjMpjI-SiA4UciCzFgv42i7opNPt-VkmjC0JGMetFmsXLOg7a-Jt_k--q_Q4axd1Hn-TUbSFH_qkeUIMF_Y69sJgA%3D%3D&href=https%3A%2F%2Fmail.google.com%2F_%2Fmail-static%2F_%2Fjs%2Fmain%2Fm_i%2Ct%2Cit%2Frt%3Dh%2Fver%3DChLH7arW7OU.en.%2Fsv%3D1%2Fam%3D!TYHFcgOpBkP0RMHS-QuYX8A6FJH69v_8LYhkoDTGeMJjj6vi6C7GnsXSyX1JhHsmRCr2x3Mf7A%2Fd%3D1%3Frel%3D1&pos=l&uiv=2&hl=en&hpc=true&hsm=true&hrc=true&uqp=false&sl=false&hs=%5B%22h_hs%22%2Cnull%2Cnull%2C%5B2%2C2%5D%5D&moleh=380&mmoleh=36&two=https%3A%2F%2Fmail.google.com&host=1&zx=0.6883780665230006&hb=1&retry_module_load=2
# 2013-09-23 10:16:07.567594 0:00:00 https://talkgadget.google.com/u/0/talkgadget/_/chat?client=sm&prop=gmail&nav=true&fid=gtn-roster-iframe-id&os=MacIntel&stime=1379902412330&xpc=%7B%22cn%22%3A%22z1nj5v%22%2C%22tp%22%3A1%2C%22ifrid%22%3A%22gtn-roster-iframe-id%22%2C%22pu%22%3A%22https%3A%2F%2Ftalkgadget.google.com%2Fu%2F0%2Ftalkgadget%2F_%2F%22%7D&ec=%5B%22ci%3Aec%22%2Ctrue%2Ctrue%2Cfalse%5D&pvt=AMP3uWZP1rjMpjI-SiA4UciCzFgv42i7opNPt-VkmjC0JGMetFmsXLOg7a-Jt_k--q_Q4axd1Hn-TUbSFH_qkeUIMF_Y69sJgA%3D%3D&href=https%3A%2F%2Fmail.google.com%2F_%2Fmail-static%2F_%2Fjs%2Fmain%2Fm_i%2Ct%2Cit%2Frt%3Dh%2Fver%3DChLH7arW7OU.en.%2Fsv%3D1%2Fam%3D!TYHFcgOpBkP0RMHS-QuYX8A6FJH69v_8LYhkoDTGeMJjj6vi6C7GnsXSyX1JhHsmRCr2x3Mf7A%2Fd%3D1%3Frel%3D1&pos=l&uiv=2&hl=en&hpc=true&hsm=true&hrc=true&uqp=false&sl=false&hs=%5B%22h_hs%22%2Cnull%2Cnull%2C%5B2%2C2%5D%5D&moleh=380&mmoleh=36&two=https%3A%2F%2Fmail.google.com&host=1&zx=0.5479450416751206&hb=1
# 2013-09-23 10:16:07.645335 0:00:00 https://mail.google.com/mail/u/0/?shva=1#inbox/1413facdb34fce5e?compose=141489a368b96d4e
# 2013-09-23 10:16:17.929707 0:00:00 https://talkgadget.google.com/u/0/talkgadget/_/chat?client=sm&prop=gmail&nav=true&fid=gtn-roster-iframe-id&os=MacIntel&stime=1379902412330&xpc=%7B%22cn%22%3A%22z1nj5v%22%2C%22tp%22%3A1%2C%22ifrid%22%3A%22gtn-roster-iframe-id%22%2C%22pu%22%3A%22https%3A%2F%2Ftalkgadget.google.com%2Fu%2F0%2Ftalkgadget%2F_%2F%22%7D&ec=%5B%22ci%3Aec%22%2Ctrue%2Ctrue%2Cfalse%5D&pvt=AMP3uWZP1rjMpjI-SiA4UciCzFgv42i7opNPt-VkmjC0JGMetFmsXLOg7a-Jt_k--q_Q4axd1Hn-TUbSFH_qkeUIMF_Y69sJgA%3D%3D&href=https%3A%2F%2Fmail.google.com%2F_%2Fmail-static%2F_%2Fjs%2Fmain%2Fm_i%2Ct%2Cit%2Frt%3Dh%2Fver%3DChLH7arW7OU.en.%2Fsv%3D1%2Fam%3D!TYHFcgOpBkP0RMHS-QuYX8A6FJH69v_8LYhkoDTGeMJjj6vi6C7GnsXSyX1JhHsmRCr2x3Mf7A%2Fd%3D1%3Frel%3D1&pos=l&uiv=2&hl=en&hpc=true&hsm=true&hrc=true&uqp=false&sl=false&hs=%5B%22h_hs%22%2Cnull%2Cnull%2C%5B2%2C2%5D%5D&moleh=380&mmoleh=36&two=https%3A%2F%2Fmail.google.com&host=1&zx=0.5479450416751206&hb=1
# 2013-09-23 10:16:17.929707 0:00:00 https://talkgadget.google.com/u/0/talkgadget/_/chat?client=sm&prop=gmail&nav=true&fid=gtn-roster-iframe-id&os=MacIntel&stime=1379902412330&xpc=%7B%22cn%22%3A%22z1nj5v%22%2C%22tp%22%3A1%2C%22ifrid%22%3A%22gtn-roster-iframe-id%22%2C%22pu%22%3A%22https%3A%2F%2Ftalkgadget.google.com%2Fu%2F0%2Ftalkgadget%2F_%2F%22%7D&ec=%5B%22ci%3Aec%22%2Ctrue%2Ctrue%2Cfalse%5D&pvt=AMP3uWZP1rjMpjI-SiA4UciCzFgv42i7opNPt-VkmjC0JGMetFmsXLOg7a-Jt_k--q_Q4axd1Hn-TUbSFH_qkeUIMF_Y69sJgA%3D%3D&href=https%3A%2F%2Fmail.google.com%2F_%2Fmail-static%2F_%2Fjs%2Fmain%2Fm_i%2Ct%2Cit%2Frt%3Dh%2Fver%3DChLH7arW7OU.en.%2Fsv%3D1%2Fam%3D!TYHFcgOpBkP0RMHS-QuYX8A6FJH69v_8LYhkoDTGeMJjj6vi6C7GnsXSyX1JhHsmRCr2x3Mf7A%2Fd%3D1%3Frel%3D1&pos=l&uiv=2&hl=en&hpc=true&hsm=true&hrc=true&uqp=false&sl=false&hs=%5B%22h_hs%22%2Cnull%2Cnull%2C%5B2%2C2%5D%5D&moleh=380&mmoleh=36&two=https%3A%2F%2Fmail.google.com&host=1&zx=0.5479450416751206&hb=1&retry_module_load=1
# 2013-09-23 10:16:26.780083 0:00:00 https://mail.google.com/mail/u/0/?shva=1#inbox/1413facdb34fce5e?compose=141489a7ca9d0baf
# 2013-09-23 10:16:33.600231 0:00:00 https://mail.google.com/mail/u/0/?shva=1#inbox/1413facdb34fce5e?compose=141489a9a2a263e3
# 2013-09-23 10:16:48.154514 0:00:00 https://mail.google.com/mail/u/0/?shva=1#inbox/1413facdb34fce5e?compose=141489ad2fef78b3
# 2013-09-23 10:16:48.399798 0:00:00 https://talkgadget.google.com/u/0/talkgadget/_/chat?client=sm&prop=gmail&nav=true&fid=gtn-roster-iframe-id&os=MacIntel&stime=1379902412330&xpc=%7B%22cn%22%3A%22z1nj5v%22%2C%22tp%22%3A1%2C%22ifrid%22%3A%22gtn-roster-iframe-id%22%2C%22pu%22%3A%22https%3A%2F%2Ftalkgadget.google.com%2Fu%2F0%2Ftalkgadget%2F_%2F%22%7D&ec=%5B%22ci%3Aec%22%2Ctrue%2Ctrue%2Cfalse%5D&pvt=AMP3uWZP1rjMpjI-SiA4UciCzFgv42i7opNPt-VkmjC0JGMetFmsXLOg7a-Jt_k--q_Q4axd1Hn-TUbSFH_qkeUIMF_Y69sJgA%3D%3D&href=https%3A%2F%2Fmail.google.com%2F_%2Fmail-static%2F_%2Fjs%2Fmain%2Fm_i%2Ct%2Cit%2Frt%3Dh%2Fver%3DChLH7arW7OU.en.%2Fsv%3D1%2Fam%3D!TYHFcgOpBkP0RMHS-QuYX8A6FJH69v_8LYhkoDTGeMJjj6vi6C7GnsXSyX1JhHsmRCr2x3Mf7A%2Fd%3D1%3Frel%3D1&pos=l&uiv=2&hl=en&hpc=true&hsm=true&hrc=true&uqp=false&sl=false&hs=%5B%22h_hs%22%2Cnull%2Cnull%2C%5B2%2C2%5D%5D&moleh=380&mmoleh=36&two=https%3A%2F%2Fmail.google.com&host=1&zx=0.5479450416751206&hb=1&retry_module_load=1
# 2013-09-23 10:16:48.399798 0:00:00 https://talkgadget.google.com/u/0/talkgadget/_/chat?client=sm&prop=gmail&nav=true&fid=gtn-roster-iframe-id&os=MacIntel&stime=1379902412330&xpc=%7B%22cn%22%3A%22z1nj5v%22%2C%22tp%22%3A1%2C%22ifrid%22%3A%22gtn-roster-iframe-id%22%2C%22pu%22%3A%22https%3A%2F%2Ftalkgadget.google.com%2Fu%2F0%2Ftalkgadget%2F_%2F%22%7D&ec=%5B%22ci%3Aec%22%2Ctrue%2Ctrue%2Cfalse%5D&pvt=AMP3uWZP1rjMpjI-SiA4UciCzFgv42i7opNPt-VkmjC0JGMetFmsXLOg7a-Jt_k--q_Q4axd1Hn-TUbSFH_qkeUIMF_Y69sJgA%3D%3D&href=https%3A%2F%2Fmail.google.com%2F_%2Fmail-static%2F_%2Fjs%2Fmain%2Fm_i%2Ct%2Cit%2Frt%3Dh%2Fver%3DChLH7arW7OU.en.%2Fsv%3D1%2Fam%3D!TYHFcgOpBkP0RMHS-QuYX8A6FJH69v_8LYhkoDTGeMJjj6vi6C7GnsXSyX1JhHsmRCr2x3Mf7A%2Fd%3D1%3Frel%3D1&pos=l&uiv=2&hl=en&hpc=true&hsm=true&hrc=true&uqp=false&sl=false&hs=%5B%22h_hs%22%2Cnull%2Cnull%2C%5B2%2C2%5D%5D&moleh=380&mmoleh=36&two=https%3A%2F%2Fmail.google.com&host=1&zx=0.5479450416751206&hb=1&retry_module_load=2

# %% [markdown]
# ##3.9 res to parsed_res: Covert time, duration, host, ...

# %%
cu.execute("SELECT urls.url, visits.visit_time, visits.visit_duration, visits.id, visits.from_visit, visits.transition, visits.segment_id, urls.id FROM visits INNER JOIN urls ON visits.url=urls.id;")
res=cu.fetchall()
parsed_res = []
for item in res:
    urlhost = urlparse.urlparse(item[0]).netloc
    parsed_res.append([urlhost, getTime(item[1]), getTime(item[2], "duration")])

# %%
for v in parsed_res[:30]:
    print "%s\t%s\t%s"%(v[1].strftime('%Y-%m-%d %H:%M:%S'), 
                            v[2].seconds,
                            v[0])
# Out:
# 2013-09-23 10:13:12	4	www.google.com.tw
# 2013-09-23 10:13:15	0	mail.google.com
# 2013-09-23 10:13:15	0	mail.google.com
# 2013-09-23 10:13:16	0	mail.google.com
# 2013-09-23 10:13:16	0	accounts.google.com
# 2013-09-23 10:13:23	118	accounts.google.com
# 2013-09-23 10:13:24	0	mail.google.com
# 2013-09-23 10:13:24	0	mail.google.com
# 2013-09-23 10:13:24	0	mail.google.com
# 2013-09-23 10:13:26	0	mail.google.com
# 2013-09-23 10:13:31	0	mail.google.com
# 2013-09-23 10:13:34	0	mail.google.com
# 2013-09-23 10:13:42	0	mail.google.com
# 2013-09-23 10:13:43	0	talkgadget.google.com
# 2013-09-23 10:13:43	0	talkgadget.google.com
# 2013-09-23 10:13:44	0	mail.google.com
# 2013-09-23 10:13:54	0	mail.google.com
# 2013-09-23 10:14:14	0	talkgadget.google.com
# 2013-09-23 10:14:14	0	talkgadget.google.com
# 2013-09-23 10:14:26	0	talkgadget.google.com
# 2013-09-23 10:14:26	0	talkgadget.google.com
# 2013-09-23 10:14:37	0	talkgadget.google.com
# 2013-09-23 10:14:37	0	talkgadget.google.com
# 2013-09-23 10:15:07	0	talkgadget.google.com
# 2013-09-23 10:15:07	0	talkgadget.google.com
# 2013-09-23 10:15:22	0	mail.google.com
# 2013-09-23 10:15:39	0	mail.google.com
# 2013-09-23 10:15:48	0	mail.google.com
# 2013-09-23 10:15:53	0	mail.google.com
# 2013-09-23 10:16:02	0	mail.google.com

# %% [markdown]
# ##3.10 Merge adjacent visits
# * 由於前述的結果，有太多mail或者talkgadget是相同的服務，我希望前後如果一樣的話，就把他銜接起來。

# %%
print "VISITS BEFORE MERGE:%d"%(len(parsed_res))
merged_visits = []
uniq_url = None
for visit in parsed_res:
    if uniq_url != visit[0]:
        uniq_url = visit[0]
        merged_visits.append([uniq_url, visit[1], visit[1]+visit[2], visit[2]])
    else:
        try:
            merged_visits[-1][2] = visit[1]+visit[2]
            merged_visits[-1][3] = visit[1] - merged_visits[-1][1] + visit[2]
        except:
            print merged_visits[-1]
print "VISITS BEFORE MERGE:%d"%(len(merged_visits))
# Out:
# VISITS BEFORE MERGE:26346
# VISITS BEFORE MERGE:6656

# %%
for v in merged_visits[:20]:
    print v[1], v[3], v[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-7dc234943a70> in <module>()
# ----> 1 for v in merged_visits[:20]:
#       2     print v[1], v[3], v[0]
#
# NameError: name 'merged_visits' is not defined

# %% [markdown]
# ##3.10.1 Filter out unneccesary or Filter in neccesary entry

# %%
def visitfilter(inlist, FILTER=None, DEL=False):
    res = []
    filter_in = ['dropbox', 'dictionary', 'facebook', 'mail', 'youtube', 'toasty', 'comic', 'dm5', 'mobile01']
    filter_out = ['account', 'ftp', 'itc']
    if FILTER == None:
        return inlist
    if FILTER == "Exclude":
        for item in inlist:
            if len([x for x in filter_out if x in item[0]])==0:
                res.append(item)
    if FILTER == "Include":
        for item in inlist:
            if len([x for x in filter_in if x in item[0]])>0:
                res.append(item)
    return res

# %%
filtered_visits = visitfilter(merged_visits, None) ##FILTER = Exclude, Include, or None
print len(filtered_visits)
print "%s\t%-14s\t%s\t%-10s"%('date', 'time', 'duration', 'url')
for r in filtered_visits[:10]:
    print "%s\t%-14s\t%s\t%-10s"%(r[1], r[2],  r[3], r[0])
# Out:
# 6656
# date	time          	duration	url
# 2013-09-23 10:13:12.405427	2013-09-23 10:13:17.168691	0:00:04.763264	www.google.com.tw
# 2013-09-23 10:13:15.839026	2013-09-23 10:13:16.831155	0:00:00.992129	mail.google.com
# 2013-09-23 10:13:16.831155	2013-09-23 10:15:22.592121	0:02:05.760966	accounts.google.com
# 2013-09-23 10:13:24.883494	2013-09-23 10:13:42.387513	0:00:17.504019	mail.google.com
# 2013-09-23 10:13:43.689719	2013-09-23 10:13:43.689719	0:00:00	talkgadget.google.com
# 2013-09-23 10:13:44.907833	2013-09-23 10:13:54.310997	0:00:09.403164	mail.google.com
# 2013-09-23 10:14:14.229230	2013-09-23 10:15:07.779116	0:00:53.549886	talkgadget.google.com
# 2013-09-23 10:15:22.592121	2013-09-23 10:16:02.620901	0:00:40.028780	mail.google.com
# 2013-09-23 10:16:07.567594	2013-09-23 10:16:07.567594	0:00:00	talkgadget.google.com
# 2013-09-23 10:16:07.645335	2013-09-23 10:16:07.645335	0:00:00	mail.google.com

# %% [markdown]
# ### First try of using Pandas
# * Tutorials http://cloga.info/python/%E6%95%B0%E6%8D%AE%E7%A7%91%E5%AD%A6/2013/09/17/pandas_intro/

# %%
import pandas as pd
df = pd.DataFrame(filtered_visits)
df.head()
# Out:
#                        0                          1  \
# 0      www.google.com.tw 2013-09-23 10:13:12.405427
# 1        mail.google.com 2013-09-23 10:13:15.839026
# 2    accounts.google.com 2013-09-23 10:13:16.831155
# 3        mail.google.com 2013-09-23 10:13:24.883494
# 4  talkgadget.google.com 2013-09-23 10:13:43.689719
#
#                            2               3
# 0 2013-09-23 10:13:17.168691 00:00:04.763264
# 1 2013-09-23 10:13:16.831155 00:00:00.992129
# 2 2013-09-23 10:15:22.592121 00:02:05.760966
# 3 2013-09-23 10:13:42.387513 00:00:17.504019
# 4 2013-09-23 10:13:43.689719        00:00:00

# %%
df.describe()
# Out:
#                      0                           1  \
# count             6656                        6656
# unique            1077                        6144
# top     www.google.com  2013-12-06 13:01:44.288070
# freq              1168                           4
# first              NaN  2013-09-12 23:40:57.320920
# last               NaN  2013-12-11 17:50:13.645286
# mean               NaN                         NaN
# std                NaN                         NaN
# min                NaN                         NaN
# 25%                NaN                         NaN
# 50%                NaN                         NaN
# 75%                NaN                         NaN
# max                NaN                         NaN
#
#                                  2                         3
# count                         6656                      6656
# unique                        6430                       NaN
# top     2013-11-18 13:29:10.514924                       NaN
# freq                             4                       NaN
# first   2013-09-17 16:35:17.866132                       NaN
# last    2013-12-11 17:51:33.883506                       NaN
# mean                           NaN    0 days 02:24:04.523481
# std                            NaN    1 days 17:58:34.317124
# min                            NaN  -1 days +06:20:27.483642
# 25%                            NaN           0 days 00:00:00
# 50%                            NaN    0 days 00:00:14.142633
# 75%                            NaN    0 days 00:02:56.764259
# max                            NaN   79 days 22:11:33.430602

# %% [markdown]
# ##3.11 Convert the time to specified string format

# %%
print filtered_visits[0]
for r in filtered_visits[:20]:
#     print "%s\t%s\t%s\t%s"%(r[0], r[1].isoformat(), r[2].isoformat(), r[3].seconds)
    print "%s\t%s\t%s\t%s"%(r[1].strftime('%Y-%m-%d %H:%M:%S'), r[2].strftime('%Y-%m-%d %H:%M:%S'), r[3].seconds, r[0])
# Out:
# [u'www.google.com.tw', datetime.datetime(2013, 9, 23, 10, 13, 12, 405427), datetime.datetime(2013, 9, 23, 10, 13, 17, 168691), datetime.timedelta(0, 4, 763264)]
# 2013-09-23 10:13:12	2013-09-23 10:13:17	4	www.google.com.tw
# 2013-09-23 10:13:15	2013-09-23 10:13:16	0	mail.google.com
# 2013-09-23 10:13:16	2013-09-23 10:15:22	125	accounts.google.com
# 2013-09-23 10:13:24	2013-09-23 10:13:42	17	mail.google.com
# 2013-09-23 10:13:43	2013-09-23 10:13:43	0	talkgadget.google.com
# 2013-09-23 10:13:44	2013-09-23 10:13:54	9	mail.google.com
# 2013-09-23 10:14:14	2013-09-23 10:15:07	53	talkgadget.google.com
# 2013-09-23 10:15:22	2013-09-23 10:16:02	40	mail.google.com
# 2013-09-23 10:16:07	2013-09-23 10:16:07	0	talkgadget.google.com
# 2013-09-23 10:16:07	2013-09-23 10:16:07	0	mail.google.com
# 2013-09-23 10:16:17	2013-09-23 10:16:17	0	talkgadget.google.com
# 2013-09-23 10:16:26	2013-09-23 10:16:48	21	mail.google.com
# 2013-09-23 10:16:48	2013-09-23 10:16:48	0	talkgadget.google.com
# 2013-09-23 10:16:57	2013-09-23 10:17:02	5	mail.google.com
# 2013-09-23 10:25:28	2013-09-23 10:27:24	116	www.google.com.tw
# 2013-09-23 10:25:34	2013-09-23 10:25:34	0	maps.google.com.tw
# 2013-09-23 10:26:36	2013-09-23 10:27:23	46	www.mapquest.com
# 2013-09-23 10:30:14	2013-09-23 10:47:59	1064	mail.google.com
# 2013-09-23 10:30:28	2013-09-23 10:30:28	0	talkgadget.google.com
# 2013-09-23 10:30:39	2013-09-23 10:30:45	5	www.google.com.tw

# %% [markdown]
# ## Report as HTML table
# * HTML TABLES http://www.w3schools.com/html/html_tables.asp
# * STEPS
#     1. open an html file and write data into html tables
#     2. using nbviewer [magic display to preview the html results](http://nbviewer.ipython.org/github/ipython/ipython/blob/1.x/examples/notebooks/Part%205%20-%20Rich%20Display%20System.ipynb)
#             from IPython.display import HTML
#             HTML('<iframe src=http://en.mobile.wikipedia.org/?useformat=mobile width=700 height=350></iframe>')
#     3. Apply [CSS style](http://www.w3schools.com/html/tryit.asp?filename=tryhtml_table_headings_left)
#             <head>
#             <style>
#             table, th, td {
#                 border: 1px solid black;
#                 border-collapse: collapse;
#             }
#             th, td {
#                 padding: 5px;
#             }
#             th {
#                 text-align: left;
#             }
#             </style>
# </head>
#     4. Apply [mouse hover (CSS Pseudo class) to change the background color of cell](http://stackoverflow.com/questions/19794433/change-font-color-and-background-in-html-on-mouseover)
#             td:hover
#             {
#                background-color:white
#             }

# %%
ftable = file("visit_table.html", 'w')
## "WRITE SOMETHING INTO FILE"
ftable.write("WRITE SOMETHING INTO FILE")
ftable.close()
from IPython.display import HTML
HTML('<iframe src=visit_table.html width=700 height=350></iframe>')
# Out:
# <iframe src=visit_table.html width=700 height=350></iframe>

# %% [markdown]
# ## Report timeline

# %%
def report(vlist, fname):
    fout=file(fname, 'w')
    fout.write('''
<script type="text/javascript" src="https://www.google.com/jsapi?autoload={'modules':[{'name':'visualization',
       'version':'1','packages':['timeline']}]}"></script>
<script type="text/javascript">

google.setOnLoadCallback(drawChart);
function drawChart() {

  var container = document.getElementById('example5.1');
  var chart = new google.visualization.Timeline(container);
  var dataTable = new google.visualization.DataTable();
  dataTable.addColumn({ type: 'string', id: 'Room' });
  dataTable.addColumn({ type: 'string', id: 'Name' });
  dataTable.addColumn({ type: 'date', id: 'Start' });
  dataTable.addColumn({ type: 'date', id: 'End' });
  dataTable.addRows([
    ''')
    for v in vlist:
        fout.write('["%s", "%s", new Date(0,0,0,%d,%d,%d), new Date(0,0,0,%d,%d,%d)],\n'%(v[1].strftime('%Y-%m-%d'), v[0], v[1].hour, v[1].minute, v[1].second, v[2].hour, v[2].minute, v[2].second))
    fout.write('''
        ]);
  var options = {
      colors:['#33ccff', '#ff66cc', '#339933','#ffcc33','#ff0000', '#333333', '#996600'],
    timeline: { rowLabelStyle: {fontName: 'Helvetica', fontSize: 24, color: '#603913' },
                barLabelStyle: { fontName: 'Garamond', fontSize: 14 } }
  };
  chart.draw(dataTable, options);
}
</script>
<div id="example5.1" style="width: 3900px; height: 1000px;"></div>
    ''')
    fout.close()

# %% [markdown]
# ## Query entry during a period...

# %%
def getPeriod(vlist, s, e):
    startTime = datetime.datetime.strptime(s, "%Y-%m-%d %H:%M:%S")
    endTime = datetime.datetime.strptime(e, "%Y-%m-%d %H:%M:%S")
    rlist=[]
    for v in vlist:
        if startTime < v[1] < endTime:
            if v[1].day != v[2].day:
                dayend = datetime.datetime.strptime(v[1].strftime('%Y-%m-%d')+" 23:59:59", "%Y-%m-%d %H:%M:%S")
                nextday = datetime.datetime.strptime(v[2].strftime('%Y-%m-%d')+" 00:00:00", "%Y-%m-%d %H:%M:%S")
#                 rlist.append([v[0], v[1], dayend, dayend-v[1]])
#                 rlist.append([v[0], nextday, v[2], v[2]-nextday])
            else:
                rlist.append(v)
    return rlist
#         if v[1] > v[2]:
#             print v[1].day, v[2].day, v[1].strftime('%Y-%m-%d %H:%M:%S'), v[2].strftime('%Y-%m-%d %H:%M:%S')
#         else:

# %%
rlist = getPeriod(merged_visits, "2013-12-01 00:00:00", "2015-01-01 00:00:00")
for r in rlist:
    print r
report(rlist, "viz.html")
# Out:
# [u'www.lib.ntnu.edu.tw', datetime.datetime(2013, 12, 1, 0, 22, 27, 72560), datetime.datetime(2013, 12, 1, 0, 22, 27, 72560), datetime.timedelta(0)]
# [u'moodle.ntnu.edu.tw', datetime.datetime(2013, 12, 1, 0, 36, 57, 655683), datetime.datetime(2013, 12, 1, 0, 36, 57, 655683), datetime.timedelta(0)]
# [u'www.facebook.com', datetime.datetime(2013, 12, 1, 0, 47, 32, 354763), datetime.datetime(2013, 12, 1, 0, 47, 42, 235117), datetime.timedelta(0, 9, 880354)]
# [u'www.yahoo.com.tw', datetime.datetime(2013, 12, 1, 11, 38, 34, 541230), datetime.datetime(2013, 12, 1, 23, 21, 8, 415050), datetime.timedelta(0, 42153, 873820)]
# [u'tw.yahoo.com', datetime.datetime(2013, 12, 1, 11, 38, 34, 541230), datetime.datetime(2013, 12, 1, 23, 21, 8, 415050), datetime.timedelta(0, 42153, 873820)]
# [u'www.mobile01.com', datetime.datetime(2013, 12, 1, 11, 23, 58, 952801), datetime.datetime(2013, 12, 1, 21, 28, 0, 804421), datetime.timedelta(0, 36241, 851620)]
# [u'moodle.ntnu.edu.tw', datetime.datetime(2013, 12, 1, 0, 36, 57, 655683), datetime.datetime(2013, 12, 1, 0, 42, 33, 798861), datetime.timedelta(0, 336, 143178)]
# [u'www.ntnu.edu.tw', datetime.datetime(2013, 12, 1, 1, 54, 15, 443757), datetime.datetime(2013, 12, 1, 1, 54, 15, 443757), datetime.timedelta(0)]
# [u'drive.google.com', datetime.datetime(2013, 12, 1, 1, 47, 24, 243662), datetime.datetime(2013, 12, 1, 23, 27, 18, 36810), datetime.timedelta(0, 77993, 793148)]
# [u'www.books.com.tw', datetime.datetime(2013, 12, 1, 11, 41, 38, 504198), datetime.datetime(2013, 12, 1, 11, 41, 38, 504198), datetime.timedelta(0)]
# [u'medium.com', datetime.datetime(2013, 12, 1, 11, 18, 0, 410547), datetime.datetime(2013, 12, 1, 11, 18, 0, 823303), datetime.timedelta(0, 0, 412756)]
# [u'graph-tool.skewed.de', datetime.datetime(2013, 12, 1, 21, 38, 58, 820533), datetime.datetime(2013, 12, 1, 23, 18, 21, 462629), datetime.timedelta(0, 5962, 642096)]
# [u'mail.google.com', datetime.datetime(2013, 12, 2, 9, 56, 38, 561853), datetime.datetime(2013, 12, 2, 9, 56, 39, 575652), datetime.timedelta(0, 1, 13799)]
# [u'www.yahoo.com.tw', datetime.datetime(2013, 12, 2, 9, 56, 43, 305807), datetime.datetime(2013, 12, 2, 9, 56, 43, 305807), datetime.timedelta(0)]
# [u'tw.yahoo.com', datetime.datetime(2013, 12, 2, 9, 56, 43, 305807), datetime.datetime(2013, 12, 2, 9, 56, 43, 305807), datetime.timedelta(0)]
# [u'tw.rd.yahoo.com', datetime.datetime(2013, 12, 2, 9, 56, 48, 125787), datetime.datetime(2013, 12, 2, 9, 56, 48, 125787), datetime.timedelta(0)]
# [u'tw.news.yahoo.com', datetime.datetime(2013, 12, 2, 9, 56, 48, 125787), datetime.datetime(2013, 12, 2, 10, 2, 53, 357298), datetime.timedelta(0, 365, 231511)]
# [u'maps.google.com', datetime.datetime(2013, 12, 2, 9, 58, 7, 190310), datetime.datetime(2013, 12, 2, 9, 58, 9, 80213), datetime.timedelta(0, 1, 889903)]
# [u'tw.news.yahoo.com', datetime.datetime(2013, 12, 2, 9, 58, 56, 416915), datetime.datetime(2013, 12, 2, 10, 39, 10, 525907), datetime.timedelta(0, 2414, 108992)]
# [u'maps.google.com', datetime.datetime(2013, 12, 2, 10, 0, 29, 505494), datetime.datetime(2013, 12, 2, 10, 0, 56, 795884), datetime.timedelta(0, 27, 290390)]
# [u'tw.news.yahoo.com', datetime.datetime(2013, 12, 2, 10, 3, 29, 565750), datetime.datetime(2013, 12, 2, 10, 7, 46, 132858), datetime.timedelta(0, 256, 567108)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 10, 6, 41, 500295), datetime.datetime(2013, 12, 2, 10, 6, 44, 407781), datetime.timedelta(0, 2, 907486)]
# [u'hk.apple.nextmedia.com', datetime.datetime(2013, 12, 2, 10, 6, 44, 773150), datetime.datetime(2013, 12, 2, 10, 7, 2, 481006), datetime.timedelta(0, 17, 707856)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 10, 6, 47, 823202), datetime.datetime(2013, 12, 2, 10, 6, 47, 823202), datetime.timedelta(0)]
# [u'mf.techbang.com', datetime.datetime(2013, 12, 2, 10, 6, 47, 875860), datetime.datetime(2013, 12, 2, 10, 7, 28, 527503), datetime.timedelta(0, 40, 651643)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 10, 6, 49, 209792), datetime.datetime(2013, 12, 2, 10, 6, 49, 209792), datetime.timedelta(0)]
# [u'udn.com', datetime.datetime(2013, 12, 2, 10, 6, 49, 257872), datetime.datetime(2013, 12, 2, 10, 7, 38, 185270), datetime.timedelta(0, 48, 927398)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 10, 6, 51, 141018), datetime.datetime(2013, 12, 2, 10, 6, 51, 141018), datetime.timedelta(0)]
# [u'news.wenweipo.com', datetime.datetime(2013, 12, 2, 10, 6, 51, 216141), datetime.datetime(2013, 12, 2, 10, 7, 43, 51243), datetime.timedelta(0, 51, 835102)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 10, 6, 51, 997995), datetime.datetime(2013, 12, 2, 10, 6, 51, 997995), datetime.timedelta(0)]
# [u'www.nownews.com', datetime.datetime(2013, 12, 2, 10, 6, 52, 344442), datetime.datetime(2013, 12, 2, 10, 7, 44, 418406), datetime.timedelta(0, 52, 73964)]
# [u'tw.news.yahoo.com', datetime.datetime(2013, 12, 2, 10, 9, 20, 834425), datetime.datetime(2013, 12, 2, 10, 10, 16, 415082), datetime.timedelta(0, 55, 580657)]
# [u'www.books.com.tw', datetime.datetime(2013, 12, 2, 10, 10, 32, 380059), datetime.datetime(2013, 12, 2, 10, 12, 42, 903027), datetime.timedelta(0, 130, 522968)]
# [u'db.books.com.tw', datetime.datetime(2013, 12, 2, 10, 12, 42, 903027), datetime.datetime(2013, 12, 2, 10, 12, 44, 384942), datetime.timedelta(0, 1, 481915)]
# [u'www.books.com.tw', datetime.datetime(2013, 12, 2, 10, 12, 55, 851002), datetime.datetime(2013, 12, 2, 10, 12, 55, 851002), datetime.timedelta(0)]
# [u'db.books.com.tw', datetime.datetime(2013, 12, 2, 10, 13, 0, 40915), datetime.datetime(2013, 12, 2, 10, 13, 0, 40915), datetime.timedelta(0)]
# [u'www.books.com.tw', datetime.datetime(2013, 12, 2, 10, 13, 2, 282923), datetime.datetime(2013, 12, 2, 10, 13, 7, 542331), datetime.timedelta(0, 5, 259408)]
# [u'db.books.com.tw', datetime.datetime(2013, 12, 2, 10, 13, 7, 542331), datetime.datetime(2013, 12, 2, 10, 13, 7, 966673), datetime.timedelta(0, 0, 424342)]
# [u'www.books.com.tw', datetime.datetime(2013, 12, 2, 10, 13, 38, 133966), datetime.datetime(2013, 12, 2, 10, 16, 10, 249564), datetime.timedelta(0, 152, 115598)]
# [u'db.books.com.tw', datetime.datetime(2013, 12, 2, 10, 16, 10, 249564), datetime.datetime(2013, 12, 2, 10, 19, 25, 780921), datetime.timedelta(0, 195, 531357)]
# [u'www.books.com.tw', datetime.datetime(2013, 12, 2, 10, 19, 41, 531845), datetime.datetime(2013, 12, 2, 10, 21, 22, 160229), datetime.timedelta(0, 100, 628384)]
# [u'www.udn.com.tw', datetime.datetime(2013, 12, 2, 10, 21, 32, 500911), datetime.datetime(2013, 12, 2, 10, 21, 32, 500911), datetime.timedelta(0)]
# [u'udn.com', datetime.datetime(2013, 12, 2, 10, 21, 32, 500911), datetime.datetime(2013, 12, 2, 10, 25, 13, 908255), datetime.timedelta(0, 221, 407344)]
# [u'travel.udn.com', datetime.datetime(2013, 12, 2, 10, 24, 15, 252948), datetime.datetime(2013, 12, 2, 10, 28, 31, 102194), datetime.timedelta(0, 255, 849246)]
# [u'ad3.udn.com', datetime.datetime(2013, 12, 2, 10, 24, 24, 913295), datetime.datetime(2013, 12, 2, 10, 24, 24, 913295), datetime.timedelta(0)]
# [u'www.unotour.com.tw', datetime.datetime(2013, 12, 2, 10, 24, 24, 913295), datetime.datetime(2013, 12, 2, 10, 28, 32, 338155), datetime.timedelta(0, 247, 424860)]
# [u'travel.udn.com', datetime.datetime(2013, 12, 2, 10, 24, 30, 162459), datetime.datetime(2013, 12, 2, 10, 28, 41, 945935), datetime.timedelta(0, 251, 783476)]
# [u'blog.udn.com', datetime.datetime(2013, 12, 2, 10, 24, 34, 415173), datetime.datetime(2013, 12, 2, 10, 32, 18, 411692), datetime.timedelta(0, 463, 996519)]
# [u'travel.udn.com', datetime.datetime(2013, 12, 2, 10, 24, 45, 411762), datetime.datetime(2013, 12, 2, 10, 34, 23, 930179), datetime.timedelta(0, 578, 518417)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 10, 27, 3, 552103), datetime.datetime(2013, 12, 2, 10, 27, 7, 184349), datetime.timedelta(0, 3, 632246)]
# [u'www.isejingu.or.jp', datetime.datetime(2013, 12, 2, 10, 27, 7, 199957), datetime.datetime(2013, 12, 2, 10, 28, 22, 131763), datetime.timedelta(0, 74, 931806)]
# [u'maps.google.com', datetime.datetime(2013, 12, 2, 10, 27, 8, 666192), datetime.datetime(2013, 12, 2, 10, 28, 19, 596131), datetime.timedelta(0, 70, 929939)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 10, 28, 28, 232983), datetime.datetime(2013, 12, 2, 10, 28, 28, 232983), datetime.timedelta(0)]
# [u'zh.wikipedia.org', datetime.datetime(2013, 12, 2, 10, 28, 28, 673980), datetime.datetime(2013, 12, 2, 10, 36, 27, 500360), datetime.timedelta(0, 478, 826380)]
# [u'www.isejingu.or.jp', datetime.datetime(2013, 12, 2, 10, 35, 44, 181126), datetime.datetime(2013, 12, 2, 10, 36, 49, 49174), datetime.timedelta(0, 64, 868048)]
# [u'zh.wikipedia.org', datetime.datetime(2013, 12, 2, 10, 35, 51, 837403), datetime.datetime(2013, 12, 2, 10, 39, 3, 777450), datetime.timedelta(0, 191, 940047)]
# [u'mail.google.com', datetime.datetime(2013, 12, 2, 10, 43, 51, 564810), datetime.datetime(2013, 12, 2, 10, 43, 52, 377706), datetime.timedelta(0, 0, 812896)]
# [u'www.ntnu.edu.tw', datetime.datetime(2013, 12, 2, 10, 43, 55, 339724), datetime.datetime(2013, 12, 2, 10, 43, 55, 339724), datetime.timedelta(0)]
# [u'www2.ntnu.edu.tw', datetime.datetime(2013, 12, 2, 10, 43, 55, 508695), datetime.datetime(2013, 12, 2, 10, 45, 0, 573649), datetime.timedelta(0, 65, 64954)]
# [u'mail.google.com', datetime.datetime(2013, 12, 2, 10, 44, 0, 100353), datetime.datetime(2013, 12, 2, 10, 44, 24, 894977), datetime.timedelta(0, 24, 794624)]
# [u'www2.ntnu.edu.tw', datetime.datetime(2013, 12, 2, 10, 45, 0, 573649), datetime.datetime(2013, 12, 2, 10, 56, 44, 171867), datetime.timedelta(0, 703, 598218)]
# [u'www.ntnu.edu.tw', datetime.datetime(2013, 12, 2, 10, 45, 6, 524249), datetime.datetime(2013, 12, 2, 10, 45, 26, 803969), datetime.timedelta(0, 20, 279720)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 10, 45, 52, 412850), datetime.datetime(2013, 12, 2, 10, 45, 55, 554251), datetime.timedelta(0, 3, 141401)]
# [u'www.wincalendar.com', datetime.datetime(2013, 12, 2, 10, 45, 55, 849660), datetime.datetime(2013, 12, 2, 10, 50, 0, 10697), datetime.timedelta(0, 244, 161037)]
# [u'www2.ntnu.edu.tw', datetime.datetime(2013, 12, 2, 10, 56, 44, 171867), datetime.datetime(2013, 12, 2, 13, 21, 56, 94218), datetime.timedelta(0, 8711, 922351)]
# [u'www.ntnu.edu.tw', datetime.datetime(2013, 12, 2, 10, 56, 48, 481365), datetime.datetime(2013, 12, 2, 13, 13, 16, 816821), datetime.timedelta(0, 8188, 335456)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 0, 9, 161943), datetime.datetime(2013, 12, 2, 11, 0, 10, 848941), datetime.timedelta(0, 1, 686998)]
# [u'www.sigchi.org', datetime.datetime(2013, 12, 2, 11, 0, 11, 748393), datetime.datetime(2013, 12, 2, 11, 0, 37, 148133), datetime.timedelta(0, 25, 399740)]
# [u'chi2014.acm.org', datetime.datetime(2013, 12, 2, 11, 0, 37, 148133), datetime.datetime(2013, 12, 2, 11, 0, 50, 41218), datetime.timedelta(0, 12, 893085)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 6, 54, 837472), datetime.datetime(2013, 12, 2, 11, 6, 58, 154582), datetime.timedelta(0, 3, 317110)]
# [u'www.sigchi.org', datetime.datetime(2013, 12, 2, 11, 6, 58, 714689), datetime.datetime(2013, 12, 2, 11, 11, 33, 668740), datetime.timedelta(0, 274, 954051)]
# [u'chi2014.acm.org', datetime.datetime(2013, 12, 2, 11, 11, 33, 668740), datetime.datetime(2013, 12, 2, 11, 53, 23, 401173), datetime.timedelta(0, 2509, 732433)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 15, 49, 718449), datetime.datetime(2013, 12, 2, 11, 15, 56, 652551), datetime.timedelta(0, 6, 934102)]
# [u'www2014.kr', datetime.datetime(2013, 12, 2, 11, 15, 58, 96777), datetime.datetime(2013, 12, 2, 11, 53, 16, 281187), datetime.timedelta(0, 2238, 184410)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 16, 29, 284181), datetime.datetime(2013, 12, 2, 11, 16, 30, 938210), datetime.timedelta(0, 1, 654029)]
# [u'www.sigchi.org', datetime.datetime(2013, 12, 2, 11, 16, 31, 548083), datetime.datetime(2013, 12, 2, 11, 52, 50, 578731), datetime.timedelta(0, 2179, 30648)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 19, 54, 779724), datetime.datetime(2013, 12, 2, 11, 19, 57, 912734), datetime.timedelta(0, 3, 133010)]
# [u'cscw.acm.org', datetime.datetime(2013, 12, 2, 11, 19, 58, 235089), datetime.datetime(2013, 12, 2, 11, 25, 9, 187712), datetime.timedelta(0, 310, 952623)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 20, 48, 221442), datetime.datetime(2013, 12, 2, 11, 20, 49, 952832), datetime.timedelta(0, 1, 731390)]
# [u'conference.researchbib.com', datetime.datetime(2013, 12, 2, 11, 20, 50, 988690), datetime.datetime(2013, 12, 2, 11, 21, 21, 577509), datetime.timedelta(0, 30, 588819)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 21, 27, 783633), datetime.datetime(2013, 12, 2, 11, 21, 29, 609533), datetime.timedelta(0, 1, 825900)]
# [u'www.worldwewant2015.org', datetime.datetime(2013, 12, 2, 11, 21, 31, 454257), datetime.datetime(2013, 12, 2, 11, 21, 53, 37421), datetime.timedelta(0, 21, 583164)]
# [u'trends.worldwewant2015.org', datetime.datetime(2013, 12, 2, 11, 21, 52, 304180), datetime.datetime(2013, 12, 2, 11, 21, 52, 371262), datetime.timedelta(0, 0, 67082)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 22, 0, 319092), datetime.datetime(2013, 12, 2, 11, 22, 0, 319092), datetime.timedelta(0)]
# [u'en.wikipedia.org', datetime.datetime(2013, 12, 2, 11, 22, 0, 752828), datetime.datetime(2013, 12, 2, 11, 22, 18, 981225), datetime.timedelta(0, 18, 228397)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 22, 4, 549121), datetime.datetime(2013, 12, 2, 11, 22, 4, 549121), datetime.timedelta(0)]
# [u'www.2015.com', datetime.datetime(2013, 12, 2, 11, 22, 5, 308992), datetime.datetime(2013, 12, 2, 11, 23, 50, 482699), datetime.timedelta(0, 105, 173707)]
# [u'www2014.wwwconference.org', datetime.datetime(2013, 12, 2, 11, 22, 18, 981225), datetime.datetime(2013, 12, 2, 11, 23, 4, 400366), datetime.timedelta(0, 45, 419141)]
# [u'www2014.kr', datetime.datetime(2013, 12, 2, 11, 23, 4, 400366), datetime.datetime(2013, 12, 2, 11, 25, 5, 821359), datetime.timedelta(0, 121, 420993)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 24, 3, 589527), datetime.datetime(2013, 12, 2, 11, 24, 3, 589527), datetime.timedelta(0)]
# [u'www.2015.com', datetime.datetime(2013, 12, 2, 11, 24, 3, 634163), datetime.datetime(2013, 12, 2, 11, 24, 4, 546980), datetime.timedelta(0, 0, 912817)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 24, 7, 387659), datetime.datetime(2013, 12, 2, 11, 24, 7, 387659), datetime.timedelta(0)]
# [u'www.iw3c2.org', datetime.datetime(2013, 12, 2, 11, 24, 7, 425870), datetime.datetime(2013, 12, 2, 11, 25, 0, 412408), datetime.timedelta(0, 52, 986538)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 25, 16, 414225), datetime.datetime(2013, 12, 2, 11, 25, 19, 984647), datetime.timedelta(0, 3, 570422)]
# [u'conference.researchbib.com', datetime.datetime(2013, 12, 2, 11, 25, 20, 100360), datetime.datetime(2013, 12, 2, 11, 27, 11, 150153), datetime.timedelta(0, 111, 49793)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 27, 22, 186347), datetime.datetime(2013, 12, 2, 11, 27, 27, 118886), datetime.timedelta(0, 4, 932539)]
# [u'www.asisonline.org', datetime.datetime(2013, 12, 2, 11, 27, 29, 213736), datetime.datetime(2013, 12, 2, 11, 27, 43, 910353), datetime.timedelta(0, 14, 696617)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 27, 46, 650436), datetime.datetime(2013, 12, 2, 11, 27, 48, 572521), datetime.timedelta(0, 1, 922085)]
# [u'www.asis.org', datetime.datetime(2013, 12, 2, 11, 27, 50, 160091), datetime.datetime(2013, 12, 2, 11, 30, 36, 570146), datetime.timedelta(0, 166, 410055)]
# [u'2014.iasummit.org', datetime.datetime(2013, 12, 2, 11, 28, 12, 364325), datetime.datetime(2013, 12, 2, 11, 30, 24, 325818), datetime.timedelta(0, 131, 961493)]
# [u'www.asis.org', datetime.datetime(2013, 12, 2, 11, 28, 23, 112900), datetime.datetime(2013, 12, 2, 11, 30, 3, 122304), datetime.timedelta(0, 100, 9404)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 28, 34, 219882), datetime.datetime(2013, 12, 2, 11, 28, 36, 466405), datetime.timedelta(0, 2, 246523)]
# [u'www.asis.org', datetime.datetime(2013, 12, 2, 11, 28, 41, 982464), datetime.datetime(2013, 12, 2, 11, 30, 42, 35352), datetime.timedelta(0, 120, 52888)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 31, 17, 659253), datetime.datetime(2013, 12, 2, 11, 31, 22, 583021), datetime.timedelta(0, 4, 923768)]
# [u'recsys.acm.org', datetime.datetime(2013, 12, 2, 11, 31, 23, 229865), datetime.datetime(2013, 12, 2, 11, 34, 37, 802763), datetime.timedelta(0, 194, 572898)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 34, 54, 207340), datetime.datetime(2013, 12, 2, 11, 34, 56, 251068), datetime.timedelta(0, 2, 43728)]
# [u'www.ubicomp.org', datetime.datetime(2013, 12, 2, 11, 34, 56, 583015), datetime.datetime(2013, 12, 2, 11, 35, 10, 345001), datetime.timedelta(0, 13, 761986)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 35, 16, 509995), datetime.datetime(2013, 12, 2, 11, 35, 16, 509995), datetime.timedelta(0)]
# [u'www.ubicomp.org', datetime.datetime(2013, 12, 2, 11, 35, 17, 348537), datetime.datetime(2013, 12, 2, 11, 35, 17, 348537), datetime.timedelta(0)]
# [u'ubicomp.org', datetime.datetime(2013, 12, 2, 11, 35, 17, 348537), datetime.datetime(2013, 12, 2, 11, 42, 37, 862747), datetime.timedelta(0, 440, 514210)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 37, 40, 474162), datetime.datetime(2013, 12, 2, 11, 37, 43, 234967), datetime.timedelta(0, 2, 760805)]
# [u'www.percom.org', datetime.datetime(2013, 12, 2, 11, 37, 44, 591522), datetime.datetime(2013, 12, 2, 11, 39, 47, 632256), datetime.timedelta(0, 123, 40734)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 37, 48, 910861), datetime.datetime(2013, 12, 2, 11, 37, 53, 762352), datetime.timedelta(0, 4, 851491)]
# [u'pervasivehealth.org', datetime.datetime(2013, 12, 2, 11, 37, 55, 48269), datetime.datetime(2013, 12, 2, 11, 42, 1, 943530), datetime.timedelta(0, 246, 895261)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 42, 14, 754459), datetime.datetime(2013, 12, 2, 11, 43, 8, 632493), datetime.timedelta(0, 53, 878034)]
# [u'www.mobilehci2013.org', datetime.datetime(2013, 12, 2, 11, 43, 9, 145259), datetime.datetime(2013, 12, 2, 11, 45, 15, 554213), datetime.timedelta(0, 126, 408954)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 43, 24, 414184), datetime.datetime(2013, 12, 2, 11, 43, 26, 3337), datetime.timedelta(0, 1, 589153)]
# [u'mobilehci.acm.org', datetime.datetime(2013, 12, 2, 11, 43, 26, 772427), datetime.datetime(2013, 12, 2, 11, 45, 12, 393579), datetime.timedelta(0, 105, 621152)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 47, 42, 717298), datetime.datetime(2013, 12, 2, 11, 47, 44, 896354), datetime.timedelta(0, 2, 179056)]
# [u'www.acm.org', datetime.datetime(2013, 12, 2, 11, 47, 45, 28380), datetime.datetime(2013, 12, 2, 11, 48, 16, 690145), datetime.timedelta(0, 31, 661765)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 50, 26, 623499), datetime.datetime(2013, 12, 2, 11, 50, 56, 323357), datetime.timedelta(0, 29, 699858)]
# [u'www.wikicfp.com', datetime.datetime(2013, 12, 2, 11, 50, 56, 868643), datetime.datetime(2013, 12, 2, 11, 51, 8, 973576), datetime.timedelta(0, 12, 104933)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 51, 11, 733155), datetime.datetime(2013, 12, 2, 11, 51, 11, 733155), datetime.timedelta(0)]
# [u'langrid.org', datetime.datetime(2013, 12, 2, 11, 51, 12, 363899), datetime.datetime(2013, 12, 2, 11, 51, 45, 423867), datetime.timedelta(0, 33, 59968)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 53, 27, 378203), datetime.datetime(2013, 12, 2, 11, 53, 30, 927437), datetime.timedelta(0, 3, 549234)]
# [u'en.wikipedia.org', datetime.datetime(2013, 12, 2, 11, 53, 31, 400549), datetime.datetime(2013, 12, 2, 13, 11, 46, 592798), datetime.timedelta(0, 4695, 192249)]
# [u'academic.research.microsoft.com', datetime.datetime(2013, 12, 2, 11, 53, 33, 2408), datetime.datetime(2013, 12, 2, 13, 11, 52, 682975), datetime.timedelta(0, 4699, 680567)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 53, 33, 838626), datetime.datetime(2013, 12, 2, 11, 53, 36, 613772), datetime.timedelta(0, 2, 775146)]
# [u'www.cs.ualberta.ca', datetime.datetime(2013, 12, 2, 11, 53, 37, 732349), datetime.datetime(2013, 12, 2, 11, 53, 37, 732349), datetime.timedelta(0)]
# [u'webdocs.cs.ualberta.ca', datetime.datetime(2013, 12, 2, 11, 53, 37, 732349), datetime.datetime(2013, 12, 2, 13, 11, 40, 991608), datetime.timedelta(0, 4683, 259259)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 54, 42, 510550), datetime.datetime(2013, 12, 2, 11, 54, 45, 258036), datetime.timedelta(0, 2, 747486)]
# [u'www.hcii2014.org', datetime.datetime(2013, 12, 2, 11, 54, 46, 865003), datetime.datetime(2013, 12, 2, 11, 57, 26, 887408), datetime.timedelta(0, 160, 22405)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 57, 31, 999208), datetime.datetime(2013, 12, 2, 11, 57, 31, 999208), datetime.timedelta(0)]
# [u'hci2013.bcs.org', datetime.datetime(2013, 12, 2, 11, 57, 32, 907046), datetime.datetime(2013, 12, 2, 11, 57, 36, 186754), datetime.timedelta(0, 3, 279708)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 57, 44, 398249), datetime.datetime(2013, 12, 2, 11, 57, 48, 324706), datetime.timedelta(0, 3, 926457)]
# [u'www.icahdq.org', datetime.datetime(2013, 12, 2, 11, 57, 49, 310161), datetime.datetime(2013, 12, 2, 11, 58, 7, 463597), datetime.timedelta(0, 18, 153436)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 57, 50, 884143), datetime.datetime(2013, 12, 2, 11, 57, 50, 884143), datetime.timedelta(0)]
# [u'www.wikicfp.com', datetime.datetime(2013, 12, 2, 11, 57, 51, 550422), datetime.datetime(2013, 12, 2, 12, 2, 27, 128813), datetime.timedelta(0, 275, 578391)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 57, 52, 654299), datetime.datetime(2013, 12, 2, 11, 57, 52, 654299), datetime.timedelta(0)]
# [u'www.conferencealerts.com', datetime.datetime(2013, 12, 2, 11, 57, 53, 175614), datetime.datetime(2013, 12, 2, 12, 0, 13, 253216), datetime.timedelta(0, 140, 77602)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 57, 55, 398990), datetime.datetime(2013, 12, 2, 11, 57, 55, 398990), datetime.timedelta(0)]
# [u'www.ieee-icc.org', datetime.datetime(2013, 12, 2, 11, 57, 56, 576610), datetime.datetime(2013, 12, 2, 11, 59, 29, 373066), datetime.timedelta(0, 92, 796456)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 57, 59, 286041), datetime.datetime(2013, 12, 2, 11, 57, 59, 286041), datetime.timedelta(0)]
# [u'en.wikipedia.org', datetime.datetime(2013, 12, 2, 11, 57, 59, 950139), datetime.datetime(2013, 12, 2, 11, 59, 5, 150312), datetime.timedelta(0, 65, 200173)]
# [u'www.icahdq.org', datetime.datetime(2013, 12, 2, 11, 58, 7, 463597), datetime.datetime(2013, 12, 2, 12, 0, 18, 5918), datetime.timedelta(0, 130, 542321)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 11, 58, 31, 839024), datetime.datetime(2013, 12, 2, 11, 58, 34, 385137), datetime.timedelta(0, 2, 546113)]
# [u'www.icahdq.org', datetime.datetime(2013, 12, 2, 11, 58, 34, 578961), datetime.datetime(2013, 12, 2, 11, 59, 21, 705093), datetime.timedelta(0, 47, 126132)]
# [u'www.ieee-icc.org', datetime.datetime(2013, 12, 2, 11, 59, 29, 373066), datetime.datetime(2013, 12, 2, 12, 0, 8, 116373), datetime.timedelta(0, 38, 743307)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 12, 0, 58, 438140), datetime.datetime(2013, 12, 2, 12, 1, 9, 162939), datetime.timedelta(0, 10, 724799)]
# [u'aied2013.memphis.edu', datetime.datetime(2013, 12, 2, 12, 1, 10, 798246), datetime.datetime(2013, 12, 2, 12, 1, 10, 798246), datetime.timedelta(0)]
# [u'sites.google.com', datetime.datetime(2013, 12, 2, 12, 1, 10, 798246), datetime.datetime(2013, 12, 2, 12, 2, 14, 556363), datetime.timedelta(0, 63, 758117)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 12, 1, 12, 601751), datetime.datetime(2013, 12, 2, 12, 2, 17, 241164), datetime.timedelta(0, 64, 639413)]
# [u'www.wikicfp.com', datetime.datetime(2013, 12, 2, 12, 2, 27, 128813), datetime.datetime(2013, 12, 2, 12, 8, 26, 560996), datetime.timedelta(0, 359, 432183)]
# [u'ht.acm.org', datetime.datetime(2013, 12, 2, 12, 6, 35, 948930), datetime.datetime(2013, 12, 2, 12, 8, 23, 950800), datetime.timedelta(0, 108, 1870)]
# [u'www.wikicfp.com', datetime.datetime(2013, 12, 2, 12, 9, 20, 86641), datetime.datetime(2013, 12, 2, 13, 10, 10, 581350), datetime.timedelta(0, 3650, 494709)]
# [u'www.youtube.com', datetime.datetime(2013, 12, 2, 12, 31, 18, 324040), datetime.datetime(2013, 12, 2, 12, 31, 57, 989132), datetime.timedelta(0, 39, 665092)]
# [u'www.wikicfp.com', datetime.datetime(2013, 12, 2, 13, 9, 23, 579851), datetime.datetime(2013, 12, 2, 13, 11, 35, 710705), datetime.timedelta(0, 132, 130854)]
# [u'academic.research.microsoft.com', datetime.datetime(2013, 12, 2, 13, 11, 52, 682975), datetime.datetime(2013, 12, 2, 13, 12, 45, 870466), datetime.timedelta(0, 53, 187491)]
# [u'go2.microsoft.com', datetime.datetime(2013, 12, 2, 13, 12, 45, 870466), datetime.datetime(2013, 12, 2, 13, 12, 45, 870466), datetime.timedelta(0)]
# [u'www.microsoft.com', datetime.datetime(2013, 12, 2, 13, 12, 45, 870466), datetime.datetime(2013, 12, 2, 13, 13, 6, 360328), datetime.timedelta(0, 20, 489862)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 13, 13, 24, 61718), datetime.datetime(2013, 12, 2, 13, 13, 28, 30579), datetime.timedelta(0, 3, 968861)]
# [u'www.wikicfp.com', datetime.datetime(2013, 12, 2, 13, 13, 28, 709826), datetime.datetime(2013, 12, 2, 13, 15, 31, 669282), datetime.timedelta(0, 122, 959456)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 13, 17, 2, 310171), datetime.datetime(2013, 12, 2, 13, 17, 2, 310171), datetime.timedelta(0)]
# [u'twitter.com', datetime.datetime(2013, 12, 2, 13, 17, 3, 109866), datetime.datetime(2013, 12, 2, 13, 17, 20, 119899), datetime.timedelta(0, 17, 10033)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 13, 17, 23, 467118), datetime.datetime(2013, 12, 2, 13, 17, 23, 467118), datetime.timedelta(0)]
# [u'academic.research.microsoft.com', datetime.datetime(2013, 12, 2, 13, 17, 26, 267940), datetime.datetime(2013, 12, 2, 13, 21, 53, 48011), datetime.timedelta(0, 266, 780071)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 13, 22, 32, 851794), datetime.datetime(2013, 12, 2, 13, 22, 34, 364988), datetime.timedelta(0, 1, 513194)]
# [u'www.wikicfp.com', datetime.datetime(2013, 12, 2, 13, 22, 35, 63586), datetime.datetime(2013, 12, 2, 13, 25, 10, 434965), datetime.timedelta(0, 155, 371379)]
# [u'mail.google.com', datetime.datetime(2013, 12, 2, 13, 24, 40, 693187), datetime.datetime(2013, 12, 2, 13, 25, 6, 138980), datetime.timedelta(0, 25, 445793)]
# [u'www.wikicfp.com', datetime.datetime(2013, 12, 2, 13, 25, 10, 434965), datetime.datetime(2013, 12, 2, 13, 48, 0, 677270), datetime.timedelta(0, 1370, 242305)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 13, 35, 23, 644249), datetime.datetime(2013, 12, 2, 13, 35, 30, 964921), datetime.timedelta(0, 7, 320672)]
# [u'www.wikicfp.com', datetime.datetime(2013, 12, 2, 13, 35, 31, 455292), datetime.datetime(2013, 12, 2, 13, 35, 36, 558986), datetime.timedelta(0, 5, 103694)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 13, 35, 38, 296826), datetime.datetime(2013, 12, 2, 13, 35, 38, 296826), datetime.timedelta(0)]
# [u'csconf.net', datetime.datetime(2013, 12, 2, 13, 35, 39, 736288), datetime.datetime(2013, 12, 2, 13, 36, 44, 954615), datetime.timedelta(0, 65, 218327)]
# [u'icsle2014.ied.edu.hk', datetime.datetime(2013, 12, 2, 13, 37, 2, 850113), datetime.datetime(2013, 12, 2, 13, 38, 15, 498742), datetime.timedelta(0, 72, 648629)]
# [u'airccse.org', datetime.datetime(2013, 12, 2, 13, 39, 50, 303162), datetime.datetime(2013, 12, 2, 13, 40, 12, 64785), datetime.timedelta(0, 21, 761623)]
# [u'www.wikicfp.com', datetime.datetime(2013, 12, 2, 13, 41, 25, 793925), datetime.datetime(2013, 12, 2, 13, 44, 10, 727316), datetime.timedelta(0, 164, 933391)]
# [u'ijcai.org', datetime.datetime(2013, 12, 2, 13, 44, 13, 503884), datetime.datetime(2013, 12, 2, 13, 44, 58, 348099), datetime.timedelta(0, 44, 844215)]
# [u'www.wikicfp.com', datetime.datetime(2013, 12, 2, 13, 50, 3, 755283), datetime.datetime(2013, 12, 2, 13, 51, 47, 334419), datetime.timedelta(0, 103, 579136)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 13, 52, 12, 853437), datetime.datetime(2013, 12, 2, 13, 52, 24, 229375), datetime.timedelta(0, 11, 375938)]
# [u'www.wikicfp.com', datetime.datetime(2013, 12, 2, 13, 52, 24, 671922), datetime.datetime(2013, 12, 2, 13, 52, 27, 424924), datetime.timedelta(0, 2, 753002)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 13, 52, 30, 953372), datetime.datetime(2013, 12, 2, 13, 52, 30, 953372), datetime.timedelta(0)]
# [u'apchiergofuture2014.or.id', datetime.datetime(2013, 12, 2, 13, 52, 31, 948825), datetime.datetime(2013, 12, 2, 13, 53, 8, 50612), datetime.timedelta(0, 36, 101787)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 13, 53, 18, 623013), datetime.datetime(2013, 12, 2, 13, 53, 40, 433868), datetime.timedelta(0, 21, 810855)]
# [u'www.aiecon.org', datetime.datetime(2013, 12, 2, 13, 53, 40, 803424), datetime.datetime(2013, 12, 2, 13, 53, 44, 803788), datetime.timedelta(0, 4, 364)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 13, 53, 48, 293041), datetime.datetime(2013, 12, 2, 13, 53, 53, 758583), datetime.timedelta(0, 5, 465542)]
# [u'www.footballexchange.co.uk', datetime.datetime(2013, 12, 2, 13, 53, 55, 475198), datetime.datetime(2013, 12, 2, 13, 54, 3, 316630), datetime.timedelta(0, 7, 841432)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 13, 54, 20, 367318), datetime.datetime(2013, 12, 2, 13, 57, 6, 810003), datetime.timedelta(0, 166, 442685)]
# [u'www.ask4research.info', datetime.datetime(2013, 12, 2, 13, 57, 11, 245526), datetime.datetime(2013, 12, 2, 14, 9, 4, 55662), datetime.timedelta(0, 712, 810136)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 13, 57, 14, 648604), datetime.datetime(2013, 12, 2, 13, 57, 14, 648604), datetime.timedelta(0)]
# [u'www.icalt.org', datetime.datetime(2013, 12, 2, 13, 57, 16, 417019), datetime.datetime(2013, 12, 2, 14, 9, 3, 95531), datetime.timedelta(0, 706, 678512)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 14, 5, 56, 681764), datetime.datetime(2013, 12, 2, 14, 5, 58, 461266), datetime.timedelta(0, 1, 779502)]
# [u'www.aaai.org', datetime.datetime(2013, 12, 2, 14, 5, 59, 42379), datetime.datetime(2013, 12, 2, 14, 8, 29, 792442), datetime.timedelta(0, 150, 750063)]
# [u'mail.google.com', datetime.datetime(2013, 12, 2, 14, 10, 4, 541367), datetime.datetime(2013, 12, 2, 14, 11, 26, 391951), datetime.timedelta(0, 81, 850584)]
# [u'drive.google.com', datetime.datetime(2013, 12, 2, 14, 25, 5, 526730), datetime.datetime(2013, 12, 2, 14, 37, 19, 576924), datetime.timedelta(0, 734, 50194)]
# [u'docs.google.com', datetime.datetime(2013, 12, 2, 14, 25, 14, 582651), datetime.datetime(2013, 12, 2, 14, 30, 53, 163183), datetime.timedelta(0, 338, 580532)]
# [u'mail.google.com', datetime.datetime(2013, 12, 2, 14, 30, 58, 381607), datetime.datetime(2013, 12, 2, 14, 37, 10, 488263), datetime.timedelta(0, 372, 106656)]
# [u'comic.sfacg.com', datetime.datetime(2013, 12, 2, 14, 37, 12, 568100), datetime.datetime(2013, 12, 2, 14, 37, 18, 142916), datetime.timedelta(0, 5, 574816)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 14, 51, 20, 535737), datetime.datetime(2013, 12, 2, 14, 51, 24, 196914), datetime.timedelta(0, 3, 661177)]
# [u'spatialdemography.org', datetime.datetime(2013, 12, 2, 14, 51, 25, 419858), datetime.datetime(2013, 12, 2, 15, 44, 38, 236051), datetime.timedelta(0, 3192, 816193)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 14, 51, 30, 667021), datetime.datetime(2013, 12, 2, 14, 51, 30, 667021), datetime.timedelta(0)]
# [u'conference.scipy.org', datetime.datetime(2013, 12, 2, 14, 51, 31, 621101), datetime.datetime(2013, 12, 2, 15, 44, 39, 851425), datetime.timedelta(0, 3188, 230324)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 14, 51, 33, 157357), datetime.datetime(2013, 12, 2, 14, 51, 33, 157357), datetime.timedelta(0)]
# [u'spanlib.sourceforge.net', datetime.datetime(2013, 12, 2, 14, 51, 33, 657207), datetime.datetime(2013, 12, 2, 15, 44, 44, 636076), datetime.timedelta(0, 3190, 978869)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 14, 51, 35, 364427), datetime.datetime(2013, 12, 2, 14, 51, 35, 364427), datetime.timedelta(0)]
# [u'link.springer.com', datetime.datetime(2013, 12, 2, 14, 51, 36, 460116), datetime.datetime(2013, 12, 2, 14, 51, 36, 460116), datetime.timedelta(0)]
# [u'www.google.com.tw', datetime.datetime(2013, 12, 2, 14, 51, 46, 969058), datetime.datetime(2013, 12, 2, 14, 52, 8, 541844), datetime.timedelta(0, 21, 572786)]
# [u'pulipuli.blogspot.com', datetime.datetime(2013, 12, 2, 14, 52, 9, 159658), datetime.datetime(2013, 12, 2, 14, 52, 9, 159658), datetime.timedelta(0)]
# [u'pulipuli.blogspot.tw', datetime.datetime(2013, 12, 2, 14, 52, 9, 159658), datetime.datetime(2013, 12, 2, 17, 25, 0, 466903), datetime.timedelta(0, 9171, 307245)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 14, 52, 32, 254174), datetime.datetime(2013, 12, 2, 14, 52, 35, 412847), datetime.timedelta(0, 3, 158673)]
# [u'www.pytables.org', datetime.datetime(2013, 12, 2, 14, 52, 36, 427700), datetime.datetime(2013, 12, 2, 14, 54, 52, 835679), datetime.timedelta(0, 136, 407979)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 14, 52, 36, 699000), datetime.datetime(2013, 12, 2, 14, 52, 36, 699000), datetime.timedelta(0)]
# [u'www.poissonboltzmann.org', datetime.datetime(2013, 12, 2, 14, 52, 38, 494363), datetime.datetime(2013, 12, 2, 14, 53, 8, 744855), datetime.timedelta(0, 30, 250492)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 14, 52, 39, 624666), datetime.datetime(2013, 12, 2, 14, 52, 39, 624666), datetime.timedelta(0)]
# [u'python.about.com', datetime.datetime(2013, 12, 2, 14, 52, 40, 221210), datetime.datetime(2013, 12, 2, 14, 52, 54, 787629), datetime.timedelta(0, 14, 566419)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 14, 52, 48, 500798), datetime.datetime(2013, 12, 2, 14, 52, 48, 500798), datetime.timedelta(0)]
# [u'www.citeulike.org', datetime.datetime(2013, 12, 2, 14, 52, 50, 14827), datetime.datetime(2013, 12, 2, 14, 52, 50, 14827), datetime.timedelta(0)]
# [u'pandas.pydata.org', datetime.datetime(2013, 12, 2, 14, 54, 56, 635304), datetime.datetime(2013, 12, 2, 14, 55, 46, 600142), datetime.timedelta(0, 49, 964838)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 14, 56, 12, 580102), datetime.datetime(2013, 12, 2, 14, 57, 20, 73034), datetime.timedelta(0, 67, 492932)]
# [u'www2.gsu.edu', datetime.datetime(2013, 12, 2, 14, 57, 21, 398280), datetime.datetime(2013, 12, 2, 14, 57, 21, 398280), datetime.timedelta(0)]
# [u'www.gsu.edu', datetime.datetime(2013, 12, 2, 14, 57, 22, 626537), datetime.datetime(2013, 12, 2, 14, 57, 22, 626537), datetime.timedelta(0)]
# [u'www2.gsu.edu', datetime.datetime(2013, 12, 2, 14, 57, 22, 626537), datetime.datetime(2013, 12, 2, 15, 10, 13, 77601), datetime.timedelta(0, 770, 451064)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 14, 58, 28, 500801), datetime.datetime(2013, 12, 2, 14, 58, 30, 927359), datetime.timedelta(0, 2, 426558)]
# [u'www.langtoninfo.com', datetime.datetime(2013, 12, 2, 14, 58, 32, 101032), datetime.datetime(2013, 12, 2, 14, 59, 3, 724693), datetime.timedelta(0, 31, 623661)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 14, 58, 38, 827206), datetime.datetime(2013, 12, 2, 14, 58, 38, 827206), datetime.timedelta(0)]
# [u'assets.cambridge.org', datetime.datetime(2013, 12, 2, 14, 58, 39, 519087), datetime.datetime(2013, 12, 2, 14, 59, 5, 300691), datetime.timedelta(0, 25, 781604)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 14, 58, 40, 699331), datetime.datetime(2013, 12, 2, 14, 58, 43, 457063), datetime.timedelta(0, 2, 757732)]
# [u'filescroptube.com', datetime.datetime(2013, 12, 2, 14, 58, 44, 406421), datetime.datetime(2013, 12, 2, 14, 59, 22, 575589), datetime.timedelta(0, 38, 169168)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 14, 58, 46, 415792), datetime.datetime(2013, 12, 2, 14, 58, 46, 415792), datetime.timedelta(0)]
# [u'ebooks.cambridge.org', datetime.datetime(2013, 12, 2, 14, 58, 47, 142668), datetime.datetime(2013, 12, 2, 14, 59, 13, 145613), datetime.timedelta(0, 26, 2945)]
# [u'link.springer.com', datetime.datetime(2013, 12, 2, 14, 58, 47, 482075), datetime.datetime(2013, 12, 2, 14, 58, 47, 482075), datetime.timedelta(0)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 14, 58, 48, 29489), datetime.datetime(2013, 12, 2, 14, 58, 48, 29489), datetime.timedelta(0)]
# [u'ge.tt', datetime.datetime(2013, 12, 2, 14, 58, 49, 11), datetime.datetime(2013, 12, 2, 14, 59, 33, 299749), datetime.timedelta(0, 44, 299738)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 14, 58, 49, 411553), datetime.datetime(2013, 12, 2, 14, 58, 49, 411553), datetime.timedelta(0)]
# [u'www.2shared.com', datetime.datetime(2013, 12, 2, 14, 58, 51, 483032), datetime.datetime(2013, 12, 2, 14, 59, 37, 889329), datetime.timedelta(0, 46, 406297)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 14, 58, 56, 715343), datetime.datetime(2013, 12, 2, 14, 58, 59, 644510), datetime.timedelta(0, 2, 929167)]
# [u'link.springer.com', datetime.datetime(2013, 12, 2, 14, 59, 22, 691069), datetime.datetime(2013, 12, 2, 14, 59, 32, 212625), datetime.timedelta(0, 9, 521556)]
# [u'www.2shared.com', datetime.datetime(2013, 12, 2, 14, 59, 37, 889329), datetime.datetime(2013, 12, 2, 14, 59, 50, 409751), datetime.timedelta(0, 12, 520422)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 15, 0, 0, 365597), datetime.datetime(2013, 12, 2, 15, 0, 8, 598825), datetime.timedelta(0, 8, 233228)]
# [u'assets.cambridge.org', datetime.datetime(2013, 12, 2, 15, 0, 8, 695620), datetime.datetime(2013, 12, 2, 15, 1, 15, 549813), datetime.timedelta(0, 66, 854193)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 15, 0, 14, 131837), datetime.datetime(2013, 12, 2, 15, 0, 14, 131837), datetime.timedelta(0)]
# [u'www.springerpub.com', datetime.datetime(2013, 12, 2, 15, 0, 14, 588800), datetime.datetime(2013, 12, 2, 15, 1, 36, 560478), datetime.timedelta(0, 81, 971678)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 15, 0, 17, 876371), datetime.datetime(2013, 12, 2, 15, 0, 25, 383610), datetime.timedelta(0, 7, 507239)]
# [u'www.openisbn.com', datetime.datetime(2013, 12, 2, 15, 0, 26, 353189), datetime.datetime(2013, 12, 2, 15, 1, 39, 846988), datetime.timedelta(0, 73, 493799)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 15, 0, 33, 53748), datetime.datetime(2013, 12, 2, 15, 1, 10, 919654), datetime.timedelta(0, 37, 865906)]
# [u'www.cengagebrain.com', datetime.datetime(2013, 12, 2, 15, 1, 11, 796084), datetime.datetime(2013, 12, 2, 15, 1, 51, 297793), datetime.timedelta(0, 39, 501709)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 15, 1, 12, 227950), datetime.datetime(2013, 12, 2, 15, 1, 12, 227950), datetime.timedelta(0)]
# [u'srmo.sagepub.com', datetime.datetime(2013, 12, 2, 15, 1, 15, 406285), datetime.datetime(2013, 12, 2, 15, 1, 58, 865542), datetime.timedelta(0, 43, 459257)]
# [u'www2.gsu.edu', datetime.datetime(2013, 12, 2, 15, 6, 9, 204587), datetime.datetime(2013, 12, 2, 15, 14, 53, 23272), datetime.timedelta(0, 523, 818685)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 15, 6, 27, 419149), datetime.datetime(2013, 12, 2, 15, 6, 44, 779815), datetime.timedelta(0, 17, 360666)]
# [u'wiki.python.org', datetime.datetime(2013, 12, 2, 15, 6, 45, 932332), datetime.datetime(2013, 12, 2, 15, 9, 48, 72485), datetime.timedelta(0, 182, 140153)]
# [u'docs.google.com', datetime.datetime(2013, 12, 2, 15, 7, 4, 858214), datetime.datetime(2013, 12, 2, 15, 8, 8, 653574), datetime.timedelta(0, 63, 795360)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 15, 8, 32, 186045), datetime.datetime(2013, 12, 2, 15, 9, 24, 496393), datetime.timedelta(0, 52, 310348)]
# [u'www.poissonboltzmann.org', datetime.datetime(2013, 12, 2, 15, 9, 24, 776218), datetime.datetime(2013, 12, 2, 15, 9, 32, 345655), datetime.timedelta(0, 7, 569437)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 15, 10, 18, 202522), datetime.datetime(2013, 12, 2, 15, 10, 20, 571065), datetime.timedelta(0, 2, 368543)]
# [u'en.wikipedia.org', datetime.datetime(2013, 12, 2, 15, 10, 21, 21411), datetime.datetime(2013, 12, 2, 15, 10, 38, 130292), datetime.timedelta(0, 17, 108881)]
# [u'mail.google.com', datetime.datetime(2013, 12, 2, 15, 11, 57, 176193), datetime.datetime(2013, 12, 2, 15, 14, 24, 331784), datetime.timedelta(0, 147, 155591)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 15, 14, 27, 931806), datetime.datetime(2013, 12, 2, 15, 19, 42, 696208), datetime.timedelta(0, 314, 764402)]
# [u'stackoverflow.com', datetime.datetime(2013, 12, 2, 15, 19, 43, 413933), datetime.datetime(2013, 12, 2, 15, 42, 5, 812175), datetime.timedelta(0, 1342, 398242)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 15, 21, 8, 753600), datetime.datetime(2013, 12, 2, 15, 21, 13, 756371), datetime.timedelta(0, 5, 2771)]
# [u'htql.net', datetime.datetime(2013, 12, 2, 15, 21, 14, 693060), datetime.datetime(2013, 12, 2, 15, 22, 21, 188263), datetime.timedelta(0, 66, 495203)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 15, 22, 46, 248541), datetime.datetime(2013, 12, 2, 15, 22, 55, 645246), datetime.timedelta(0, 9, 396705)]
# [u'stackoverflow.com', datetime.datetime(2013, 12, 2, 15, 22, 56, 109377), datetime.datetime(2013, 12, 2, 15, 23, 30, 198459), datetime.timedelta(0, 34, 89082)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 15, 23, 3, 220623), datetime.datetime(2013, 12, 2, 15, 23, 3, 220623), datetime.timedelta(0)]
# [u'www.sourcecodeonline.com', datetime.datetime(2013, 12, 2, 15, 23, 4, 214212), datetime.datetime(2013, 12, 2, 15, 23, 34, 671974), datetime.timedelta(0, 30, 457762)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 15, 23, 5, 711351), datetime.datetime(2013, 12, 2, 15, 23, 5, 711351), datetime.timedelta(0)]
# [u'www.tanglei.name', datetime.datetime(2013, 12, 2, 15, 23, 6, 807369), datetime.datetime(2013, 12, 2, 15, 41, 49, 515345), datetime.timedelta(0, 1122, 707976)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 15, 23, 7, 914094), datetime.datetime(2013, 12, 2, 15, 23, 14, 235492), datetime.timedelta(0, 6, 321398)]
# [u'github.com', datetime.datetime(2013, 12, 2, 15, 23, 15, 305096), datetime.datetime(2013, 12, 2, 15, 41, 56, 265417), datetime.timedelta(0, 1120, 960321)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 15, 23, 17, 980071), datetime.datetime(2013, 12, 2, 15, 23, 17, 980071), datetime.timedelta(0)]
# [u'bytes.com', datetime.datetime(2013, 12, 2, 15, 23, 18, 475531), datetime.datetime(2013, 12, 2, 15, 42, 2, 786553), datetime.timedelta(0, 1124, 311022)]
# [u'www.google.com', datetime.datetime(2013, 12, 2, 15, 23, 18, 818612), datetime.datetime(2013, 12, 2, 15, 42, 3, 722354), datetime.timedelta(0, 1124, 903742)]
# [u'www.tanglei.name', datetime.datetime(2013, 12, 2, 15, 24, 14, 4136), datetime.datetime(2013, 12, 2, 15, 41, 13, 616827), datetime.timedelta(0, 1019, 612691)]
# [u'pulipuli.blogspot.com', datetime.datetime(2013, 12, 2, 15, 42, 19, 525889), datetime.datetime(2013, 12, 2, 15, 42, 19, 525889), datetime.timedelta(0)]
# [u'pulipuli.blogspot.tw', datetime.datetime(2013, 12, 2, 15, 42, 19, 525889), datetime.datetime(2013, 12, 2, 15, 42, 19, 525889), datetime.timedelta(0)]
# [u'link.springer.com', datetime.datetime(2013, 12, 2, 15, 44, 44, 713950), datetime.datetime(2013, 12, 2, 15, 44, 46, 798096), datetime.timedelta(0, 2, 84146)]
# [u'mail.google.com', datetime.datetime(2013, 12, 2, 15, 45, 37, 924790), datetime.datetime(2013, 12, 2, 17, 22, 55, 753349), datetime.timedelta(0, 5837, 828559)]
# [u'edugate.fss.uu.nl', datetime.datetime(2013, 12, 2, 17, 23, 34, 633772), datetime.datetime(2013, 12, 2, 17, 23, 50, 598709), datetime.timedelta(0, 15, 964937)]
# [u'pulipuli.blogspot.tw', datetime.datetime(2013, 12, 2, 17, 25, 0, 466903), datetime.datetime(2013, 12, 2, 17, 25, 33, 648727), datetime.timedelta(0, 33, 181824)]
# [u'comic.sfacg.com', datetime.datetime(2013, 12, 2, 21, 24, 58, 210728), datetime.datetime(2013, 12, 2, 21, 24, 58, 210728), datetime.timedelta(0)]
# [u'www.facebook.com', datetime.datetime(2013, 12, 2, 21, 25, 5, 959807), datetime.datetime(2013, 12, 2, 21, 28, 47, 19028), datetime.timedelta(0, 221, 59221)]
# [u'www.mobile01.com', datetime.datetime(2013, 12, 2, 21, 28, 48, 10181), datetime.datetime(2013, 12, 2, 21, 28, 48, 10181), datetime.timedelta(0)]
# [u'www.facebook.com', datetime.datetime(2013, 12, 2, 21, 28, 52, 142713), datetime.datetime(2013, 12, 2, 22, 38, 29, 444766), datetime.timedelta(0, 4177, 302053)]
# [u'drive.google.com', datetime.datetime(2013, 12, 2, 21, 36, 22, 816109), datetime.datetime(2013, 12, 2, 22, 38, 45, 869294), datetime.timedelta(0, 3743, 53185)]
# [u'www.facebook.com', datetime.datetime(2013, 12, 2, 22, 44, 18, 986484), datetime.datetime(2013, 12, 2, 22, 58, 19, 722850), datetime.timedelta(0, 840, 736366)]
# [u'mail.google.com', datetime.datetime(2013, 12, 2, 23, 1, 32, 978851), datetime.datetime(2013, 12, 2, 23, 1, 32, 978851), datetime.timedelta(0)]
# [u'www.facebook.com', datetime.datetime(2013, 12, 2, 22, 38, 29, 444766), datetime.datetime(2013, 12, 2, 23, 1, 48, 229862), datetime.timedelta(0, 1398, 785096)]
# [u'www.mobile01.com', datetime.datetime(2013, 12, 2, 21, 31, 16, 452115), datetime.datetime(2013, 12, 2, 23, 1, 58, 215126), datetime.timedelta(0, 5441, 763011)]
# [u'www.yahoo.com.tw', datetime.datetime(2013, 12, 2, 21, 33, 21, 566280), datetime.datetime(2013, 12, 2, 23, 11, 22, 407901), datetime.timedelta(0, 5880, 841621)]
# [u'drive.google.com', datetime.datetime(2013, 12, 2, 23, 11, 36, 547537), datetime.datetime(2013, 12, 2, 23, 11, 36, 547537), datetime.timedelta(0)]
# [u'www.facebook.com', datetime.datetime(2013, 12, 3, 0, 15, 26, 412267), datetime.datetime(2013, 12, 3, 0, 28, 1, 724853), datetime.timedelta(0, 755, 312586)]
# [u'www.lib.ntnu.edu.tw', datetime.datetime(2013, 12, 3, 0, 30, 9, 701092), datetime.datetime(2013, 12, 3, 0, 30, 9, 701092), datetime.timedelta(0)]
# [u'www.ntu.edu.tw', datetime.datetime(2013, 12, 3, 0, 31, 0, 893657), datetime.datetime(2013, 12, 3, 0, 31, 0, 893657), datetime.timedelta(0)]
# [u'www.lib.ntu.edu.tw', datetime.datetime(2013, 12, 3, 0, 31, 7, 836255), datetime.datetime(2013, 12, 3, 0, 31, 7, 836255), datetime.timedelta(0)]
# [u'www.lib.nctu.edu.tw', datetime.datetime(2013, 12, 3, 0, 31, 29, 375146), datetime.datetime(2013, 12, 3, 0, 31, 29, 375146), datetime.timedelta(0)]
# [u'www.lib.nccu.edu.tw', datetime.datetime(2013, 12, 3, 0, 31, 52, 996457), datetime.datetime(2013, 12, 3, 0, 31, 52, 996457), datetime.timedelta(0)]
# [u'www.nthu.edu.tw', datetime.datetime(2013, 12, 3, 0, 32, 10, 363293), datetime.datetime(2013, 12, 3, 0, 32, 10, 363293), datetime.timedelta(0)]
# [u'www.lib.nthu.edu.tw', datetime.datetime(2013, 12, 3, 0, 32, 16, 870590), datetime.datetime(2013, 12, 3, 0, 32, 16, 870590), datetime.timedelta(0)]
# [u'www.facebook.com', datetime.datetime(2013, 12, 3, 1, 10, 48, 211390), datetime.datetime(2013, 12, 3, 1, 43, 27, 639594), datetime.timedelta(0, 1959, 428204)]
# [u'mail.google.com', datetime.datetime(2013, 12, 3, 10, 2, 20, 514256), datetime.datetime(2013, 12, 3, 10, 2, 22, 324856), datetime.timedelta(0, 1, 810600)]
# [u'www.yahoo.com.tw', datetime.datetime(2013, 12, 3, 10, 2, 35, 942593), datetime.datetime(2013, 12, 3, 10, 2, 35, 942593), datetime.timedelta(0)]
# [u'tw.yahoo.com', datetime.datetime(2013, 12, 3, 10, 2, 35, 942593), datetime.datetime(2013, 12, 3, 10, 2, 35, 942593), datetime.timedelta(0)]
# [u'tw.rd.yahoo.com', datetime.datetime(2013, 12, 3, 10, 2, 43, 668094), datetime.datetime(2013, 12, 3, 10, 2, 43, 668094), datetime.timedelta(0)]
# [u'tw.news.yahoo.com', datetime.datetime(2013, 12, 3, 10, 2, 43, 668094), datetime.datetime(2013, 12, 3, 10, 4, 13, 386079), datetime.timedelta(0, 89, 717985)]
# [u'www.google.com', datetime.datetime(2013, 12, 3, 10, 4, 6, 347640), datetime.datetime(2013, 12, 3, 10, 4, 8, 972721), datetime.timedelta(0, 2, 625081)]
# [u'zh.wikipedia.org', datetime.datetime(2013, 12, 3, 10, 4, 9, 443764), datetime.datetime(2013, 12, 3, 10, 5, 39, 42134), datetime.timedelta(0, 89, 598370)]
# ...
# [u'www.google.com', datetime.datetime(2013, 12, 11, 14, 9, 34, 129365), datetime.datetime(2013, 12, 11, 14, 9, 38, 678200), datetime.timedelta(0, 4, 548835)]
# [u'www.taobao.com', datetime.datetime(2013, 12, 11, 14, 9, 53, 72871), datetime.datetime(2013, 12, 11, 15, 48, 24, 261050), datetime.timedelta(0, 5911, 188179)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 14, 9, 57, 754103), datetime.datetime(2013, 12, 11, 14, 10, 11, 903057), datetime.timedelta(0, 14, 148954)]
# [u'www.shopping.com', datetime.datetime(2013, 12, 11, 14, 10, 12, 723199), datetime.datetime(2013, 12, 11, 15, 48, 25, 82580), datetime.timedelta(0, 5892, 359381)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 14, 10, 16, 692096), datetime.datetime(2013, 12, 11, 14, 10, 18, 369788), datetime.timedelta(0, 1, 677692)]
# [u'www.tamron.com.hk', datetime.datetime(2013, 12, 11, 14, 10, 18, 796558), datetime.datetime(2013, 12, 11, 15, 50, 27, 759297), datetime.timedelta(0, 6008, 962739)]
# [u'www.tamron.co.jp', datetime.datetime(2013, 12, 11, 14, 11, 42, 51646), datetime.datetime(2013, 12, 11, 15, 50, 28, 554008), datetime.timedelta(0, 5926, 502362)]
# [u'mail.google.com', datetime.datetime(2013, 12, 11, 14, 11, 54, 445840), datetime.datetime(2013, 12, 11, 15, 26, 22, 994553), datetime.timedelta(0, 4468, 548713)]
# [u'www.ebay.com', datetime.datetime(2013, 12, 11, 15, 26, 47, 356067), datetime.datetime(2013, 12, 11, 15, 50, 25, 597752), datetime.timedelta(0, 1418, 241685)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 15, 27, 47, 212325), datetime.datetime(2013, 12, 11, 15, 27, 49, 704912), datetime.timedelta(0, 2, 492587)]
# [u'www.tamron-usa.com', datetime.datetime(2013, 12, 11, 15, 27, 50, 153657), datetime.datetime(2013, 12, 11, 15, 28, 11, 686213), datetime.timedelta(0, 21, 532556)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 15, 27, 51, 97764), datetime.datetime(2013, 12, 11, 15, 27, 51, 97764), datetime.timedelta(0)]
# [u'www.tamron-usa.com', datetime.datetime(2013, 12, 11, 15, 27, 51, 372228), datetime.datetime(2013, 12, 11, 15, 28, 22, 722327), datetime.timedelta(0, 31, 350099)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 15, 27, 58, 280242), datetime.datetime(2013, 12, 11, 15, 27, 58, 280242), datetime.timedelta(0)]
# [u'www.tamron.co.jp', datetime.datetime(2013, 12, 11, 15, 27, 58, 425668), datetime.datetime(2013, 12, 11, 15, 52, 6, 981414), datetime.timedelta(0, 1448, 555746)]
# [u'www.tamron-usa.com', datetime.datetime(2013, 12, 11, 15, 28, 22, 722327), datetime.datetime(2013, 12, 11, 15, 52, 12, 521405), datetime.timedelta(0, 1429, 799078)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 15, 28, 45, 668536), datetime.datetime(2013, 12, 11, 15, 28, 47, 947071), datetime.timedelta(0, 2, 278535)]
# [u'www.bhphotovideo.com', datetime.datetime(2013, 12, 11, 15, 28, 48, 860785), datetime.datetime(2013, 12, 11, 15, 29, 21, 771029), datetime.timedelta(0, 32, 910244)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 15, 28, 49, 108546), datetime.datetime(2013, 12, 11, 15, 28, 50, 71418), datetime.timedelta(0, 0, 962872)]
# [u'shopper.cnet.com', datetime.datetime(2013, 12, 11, 15, 28, 50, 448563), datetime.datetime(2013, 12, 11, 15, 29, 22, 747394), datetime.timedelta(0, 32, 298831)]
# [u'shopping.yahoo.com', datetime.datetime(2013, 12, 11, 15, 28, 50, 855957), datetime.datetime(2013, 12, 11, 15, 29, 24, 386471), datetime.timedelta(0, 33, 530514)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 15, 29, 27, 305706), datetime.datetime(2013, 12, 11, 15, 29, 27, 305706), datetime.timedelta(0)]
# [u'www.bhphotovideo.com', datetime.datetime(2013, 12, 11, 15, 29, 27, 954128), datetime.datetime(2013, 12, 11, 15, 29, 29, 492713), datetime.timedelta(0, 1, 538585)]
# [u'www.tamron.co.jp', datetime.datetime(2013, 12, 11, 15, 29, 45, 376253), datetime.datetime(2013, 12, 11, 15, 51, 43, 711662), datetime.timedelta(0, 1318, 335409)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 15, 30, 22, 789682), datetime.datetime(2013, 12, 11, 15, 30, 30, 413248), datetime.timedelta(0, 7, 623566)]
# [u'goods.ruten.com.tw', datetime.datetime(2013, 12, 11, 15, 30, 30, 623077), datetime.datetime(2013, 12, 11, 15, 32, 42, 154325), datetime.timedelta(0, 131, 531248)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 15, 30, 32, 633270), datetime.datetime(2013, 12, 11, 15, 30, 32, 633270), datetime.timedelta(0)]
# [u'goods.ruten.com.tw', datetime.datetime(2013, 12, 11, 15, 30, 32, 915347), datetime.datetime(2013, 12, 11, 15, 31, 1, 98903), datetime.timedelta(0, 28, 183556)]
# [u'class.ruten.com.tw', datetime.datetime(2013, 12, 11, 15, 31, 6, 57775), datetime.datetime(2013, 12, 11, 15, 31, 6, 57775), datetime.timedelta(0)]
# [u'goods.ruten.com.tw', datetime.datetime(2013, 12, 11, 15, 31, 8, 298440), datetime.datetime(2013, 12, 11, 15, 31, 10, 332921), datetime.timedelta(0, 2, 34481)]
# [u'class.ruten.com.tw', datetime.datetime(2013, 12, 11, 15, 31, 15, 822224), datetime.datetime(2013, 12, 11, 15, 31, 15, 822224), datetime.timedelta(0)]
# [u'goods.ruten.com.tw', datetime.datetime(2013, 12, 11, 15, 31, 41, 792871), datetime.datetime(2013, 12, 11, 15, 31, 41, 792871), datetime.timedelta(0)]
# [u'class.ruten.com.tw', datetime.datetime(2013, 12, 11, 15, 32, 0, 815533), datetime.datetime(2013, 12, 11, 15, 32, 3, 301138), datetime.timedelta(0, 2, 485605)]
# [u'mybid.ruten.com.tw', datetime.datetime(2013, 12, 11, 15, 32, 3, 301138), datetime.datetime(2013, 12, 11, 15, 32, 25, 287724), datetime.timedelta(0, 21, 986586)]
# [u'class.ruten.com.tw', datetime.datetime(2013, 12, 11, 15, 32, 25, 287724), datetime.datetime(2013, 12, 11, 15, 32, 28, 570502), datetime.timedelta(0, 3, 282778)]
# [u'mybid.ruten.com.tw', datetime.datetime(2013, 12, 11, 15, 32, 28, 570502), datetime.datetime(2013, 12, 11, 15, 32, 40, 110709), datetime.timedelta(0, 11, 540207)]
# [u'goods.ruten.com.tw', datetime.datetime(2013, 12, 11, 15, 32, 42, 154325), datetime.datetime(2013, 12, 11, 15, 51, 16, 843766), datetime.timedelta(0, 1114, 689441)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 15, 33, 11, 85187), datetime.datetime(2013, 12, 11, 15, 33, 11, 85187), datetime.timedelta(0)]
# [u'goods.ruten.com.tw', datetime.datetime(2013, 12, 11, 15, 33, 11, 327857), datetime.datetime(2013, 12, 11, 15, 41, 50, 105130), datetime.timedelta(0, 518, 777273)]
# [u'www.tamron.co.jp', datetime.datetime(2013, 12, 11, 15, 33, 25, 450798), datetime.datetime(2013, 12, 11, 15, 51, 40, 414887), datetime.timedelta(0, 1094, 964089)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 15, 42, 5, 784185), datetime.datetime(2013, 12, 11, 15, 42, 5, 784185), datetime.timedelta(0)]
# [u'www.tamron.com.hk', datetime.datetime(2013, 12, 11, 15, 42, 6, 218592), datetime.datetime(2013, 12, 11, 15, 51, 27, 326578), datetime.timedelta(0, 561, 107986)]
# [u'www.tamron.co.jp', datetime.datetime(2013, 12, 11, 15, 42, 13, 477102), datetime.datetime(2013, 12, 11, 15, 42, 30, 443371), datetime.timedelta(0, 16, 966269)]
# [u'mail.google.com', datetime.datetime(2013, 12, 11, 15, 42, 37, 570880), datetime.datetime(2013, 12, 11, 15, 48, 0, 263173), datetime.timedelta(0, 322, 692293)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 15, 48, 3, 195866), datetime.datetime(2013, 12, 11, 15, 51, 15, 173515), datetime.timedelta(0, 191, 977649)]
# [u'mail.google.com', datetime.datetime(2013, 12, 11, 15, 48, 30, 771570), datetime.datetime(2013, 12, 11, 15, 48, 49, 836893), datetime.timedelta(0, 19, 65323)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 15, 48, 51, 893077), datetime.datetime(2013, 12, 11, 15, 51, 27, 808710), datetime.timedelta(0, 155, 915633)]
# [u'mail.google.com', datetime.datetime(2013, 12, 11, 15, 49, 37, 799411), datetime.datetime(2013, 12, 11, 15, 50, 22, 508056), datetime.timedelta(0, 44, 708645)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 15, 50, 33, 78664), datetime.datetime(2013, 12, 11, 15, 50, 40, 331167), datetime.timedelta(0, 7, 252503)]
# [u'goods.ruten.com.tw', datetime.datetime(2013, 12, 11, 15, 50, 40, 475154), datetime.datetime(2013, 12, 11, 15, 50, 51, 964251), datetime.timedelta(0, 11, 489097)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 15, 50, 41, 189170), datetime.datetime(2013, 12, 11, 15, 50, 41, 189170), datetime.timedelta(0)]
# [u'goods.ruten.com.tw', datetime.datetime(2013, 12, 11, 15, 50, 41, 396744), datetime.datetime(2013, 12, 11, 15, 50, 57, 424313), datetime.timedelta(0, 16, 27569)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 15, 51, 1, 903068), datetime.datetime(2013, 12, 11, 15, 51, 1, 903068), datetime.timedelta(0)]
# [u'shopping.yahoo.com', datetime.datetime(2013, 12, 11, 15, 51, 2, 459344), datetime.datetime(2013, 12, 11, 15, 51, 10, 335149), datetime.timedelta(0, 7, 875805)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 15, 51, 5, 278421), datetime.datetime(2013, 12, 11, 15, 51, 32, 719950), datetime.timedelta(0, 27, 441529)]
# [u'tc.diytrade.com', datetime.datetime(2013, 12, 11, 15, 51, 32, 924717), datetime.datetime(2013, 12, 11, 15, 51, 36, 848515), datetime.timedelta(0, 3, 923798)]
# [u'www.tamron.co.jp', datetime.datetime(2013, 12, 11, 15, 51, 50, 353474), datetime.datetime(2013, 12, 11, 15, 52, 0, 828688), datetime.timedelta(0, 10, 475214)]
# [u'mail.google.com', datetime.datetime(2013, 12, 11, 15, 53, 15, 409585), datetime.datetime(2013, 12, 11, 16, 4, 59, 286253), datetime.timedelta(0, 703, 876668)]
# [u'www.yahoo.com.tw', datetime.datetime(2013, 12, 11, 16, 3, 27, 993888), datetime.datetime(2013, 12, 11, 16, 3, 27, 993888), datetime.timedelta(0)]
# [u'tw.yahoo.com', datetime.datetime(2013, 12, 11, 16, 3, 27, 993888), datetime.datetime(2013, 12, 11, 16, 3, 27, 993888), datetime.timedelta(0)]
# [u'tw.rd.yahoo.com', datetime.datetime(2013, 12, 11, 16, 3, 31, 471900), datetime.datetime(2013, 12, 11, 16, 3, 31, 471900), datetime.timedelta(0)]
# [u'tw.news.yahoo.com', datetime.datetime(2013, 12, 11, 16, 3, 31, 471900), datetime.datetime(2013, 12, 11, 16, 3, 33, 811155), datetime.timedelta(0, 2, 339255)]
# [u'mail.google.com', datetime.datetime(2013, 12, 11, 16, 3, 35, 656331), datetime.datetime(2013, 12, 11, 16, 5, 1, 819027), datetime.timedelta(0, 86, 162696)]
# [u'goods.ruten.com.tw', datetime.datetime(2013, 12, 11, 16, 4, 33, 460053), datetime.datetime(2013, 12, 11, 16, 4, 38, 624918), datetime.timedelta(0, 5, 164865)]
# [u'mybid.ruten.com.tw', datetime.datetime(2013, 12, 11, 16, 4, 38, 624918), datetime.datetime(2013, 12, 11, 16, 4, 54, 441673), datetime.timedelta(0, 15, 816755)]
# [u'www.yahoo.com.tw', datetime.datetime(2013, 12, 11, 16, 4, 57, 325801), datetime.datetime(2013, 12, 11, 16, 4, 57, 325801), datetime.timedelta(0)]
# [u'tw.yahoo.com', datetime.datetime(2013, 12, 11, 16, 4, 57, 325801), datetime.datetime(2013, 12, 11, 16, 4, 58, 741819), datetime.timedelta(0, 1, 416018)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 16, 19, 45, 126552), datetime.datetime(2013, 12, 11, 16, 19, 49, 698446), datetime.timedelta(0, 4, 571894)]
# [u'narrativeresearch.ndhu.edu.tw', datetime.datetime(2013, 12, 11, 16, 19, 49, 920950), datetime.datetime(2013, 12, 11, 16, 19, 53, 361484), datetime.timedelta(0, 3, 440534)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 16, 19, 57, 908997), datetime.datetime(2013, 12, 11, 16, 19, 57, 908997), datetime.timedelta(0)]
# [u'ndltd.ncl.edu.tw', datetime.datetime(2013, 12, 11, 16, 19, 59, 190699), datetime.datetime(2013, 12, 11, 16, 21, 8, 717866), datetime.timedelta(0, 69, 527167)]
# [u'mail.google.com', datetime.datetime(2013, 12, 11, 16, 23, 43, 156639), datetime.datetime(2013, 12, 11, 16, 25, 59, 14721), datetime.timedelta(0, 135, 858082)]
# [u'www.yahoo.com.tw', datetime.datetime(2013, 12, 11, 16, 24, 18, 948494), datetime.datetime(2013, 12, 11, 16, 24, 18, 948494), datetime.timedelta(0)]
# [u'tw.yahoo.com', datetime.datetime(2013, 12, 11, 16, 24, 18, 948494), datetime.datetime(2013, 12, 11, 16, 24, 18, 948494), datetime.timedelta(0)]
# [u'tw.rd.yahoo.com', datetime.datetime(2013, 12, 11, 16, 24, 26, 890699), datetime.datetime(2013, 12, 11, 16, 24, 26, 890699), datetime.timedelta(0)]
# [u'tw.news.yahoo.com', datetime.datetime(2013, 12, 11, 16, 24, 26, 890699), datetime.datetime(2013, 12, 11, 16, 25, 57, 813600), datetime.timedelta(0, 90, 922901)]
# [u'mail.google.com', datetime.datetime(2013, 12, 11, 16, 46, 9, 858574), datetime.datetime(2013, 12, 11, 16, 46, 21, 514624), datetime.timedelta(0, 11, 656050)]
# [u'comic.sfacg.com', datetime.datetime(2013, 12, 11, 16, 46, 26, 359677), datetime.datetime(2013, 12, 11, 16, 51, 27, 246570), datetime.timedelta(0, 300, 886893)]
# [u'www.youtube.com', datetime.datetime(2013, 12, 11, 16, 51, 58, 490634), datetime.datetime(2013, 12, 11, 17, 3, 16, 589131), datetime.timedelta(0, 678, 98497)]
# [u'mail.google.com', datetime.datetime(2013, 12, 11, 17, 3, 31, 416646), datetime.datetime(2013, 12, 11, 17, 7, 9, 165189), datetime.timedelta(0, 217, 748543)]
# [u'www.yahoo.com.tw', datetime.datetime(2013, 12, 11, 17, 3, 36, 405669), datetime.datetime(2013, 12, 11, 17, 3, 36, 405669), datetime.timedelta(0)]
# [u'tw.yahoo.com', datetime.datetime(2013, 12, 11, 17, 3, 36, 405669), datetime.datetime(2013, 12, 11, 17, 3, 41, 652650), datetime.timedelta(0, 5, 246981)]
# [u'www.yahoo.com.tw', datetime.datetime(2013, 12, 11, 17, 3, 44, 450395), datetime.datetime(2013, 12, 11, 17, 3, 44, 450395), datetime.timedelta(0)]
# [u'tw.yahoo.com', datetime.datetime(2013, 12, 11, 17, 3, 44, 450395), datetime.datetime(2013, 12, 11, 17, 3, 44, 450395), datetime.timedelta(0)]
# [u'tw.rd.yahoo.com', datetime.datetime(2013, 12, 11, 17, 3, 47, 378512), datetime.datetime(2013, 12, 11, 17, 3, 47, 378512), datetime.timedelta(0)]
# [u'tw.news.yahoo.com', datetime.datetime(2013, 12, 11, 17, 3, 47, 378512), datetime.datetime(2013, 12, 11, 17, 6, 58, 530498), datetime.timedelta(0, 191, 151986)]
# [u'mail.google.com', datetime.datetime(2013, 12, 11, 17, 10, 13, 607442), datetime.datetime(2013, 12, 11, 17, 12, 56, 152106), datetime.timedelta(0, 162, 544664)]
# [u'www.yahoo.com.tw', datetime.datetime(2013, 12, 11, 17, 10, 18, 395224), datetime.datetime(2013, 12, 11, 17, 10, 18, 395224), datetime.timedelta(0)]
# [u'tw.yahoo.com', datetime.datetime(2013, 12, 11, 17, 10, 18, 395224), datetime.datetime(2013, 12, 11, 17, 10, 20, 779491), datetime.timedelta(0, 2, 384267)]
# [u'www.yahoo.com.tw', datetime.datetime(2013, 12, 11, 17, 12, 45, 933145), datetime.datetime(2013, 12, 11, 17, 12, 45, 933145), datetime.timedelta(0)]
# [u'tw.yahoo.com', datetime.datetime(2013, 12, 11, 17, 12, 45, 933145), datetime.datetime(2013, 12, 11, 17, 12, 45, 933145), datetime.timedelta(0)]
# [u'tw.rd.yahoo.com', datetime.datetime(2013, 12, 11, 17, 12, 51, 832827), datetime.datetime(2013, 12, 11, 17, 12, 51, 832827), datetime.timedelta(0)]
# [u'tw.news.yahoo.com', datetime.datetime(2013, 12, 11, 17, 12, 51, 832827), datetime.datetime(2013, 12, 11, 17, 12, 55, 158278), datetime.timedelta(0, 3, 325451)]
# [u'mail.google.com', datetime.datetime(2013, 12, 11, 17, 13, 2, 905946), datetime.datetime(2013, 12, 11, 17, 42, 17, 587540), datetime.timedelta(0, 1754, 681594)]
# [u'comic.sfacg.com', datetime.datetime(2013, 12, 11, 17, 37, 21, 37189), datetime.datetime(2013, 12, 11, 17, 42, 11, 24399), datetime.timedelta(0, 289, 987210)]
# [u'mail.google.com', datetime.datetime(2013, 12, 11, 17, 42, 23, 794649), datetime.datetime(2013, 12, 11, 17, 42, 26, 58833), datetime.timedelta(0, 2, 264184)]
# [u'sites.google.com', datetime.datetime(2013, 12, 11, 17, 42, 30, 172291), datetime.datetime(2013, 12, 11, 17, 43, 8, 47947), datetime.timedelta(0, 37, 875656)]
# [u'www.google.com', datetime.datetime(2013, 12, 11, 17, 45, 2, 425893), datetime.datetime(2013, 12, 11, 17, 45, 3, 999518), datetime.timedelta(0, 1, 573625)]
# [u'macs.about.com', datetime.datetime(2013, 12, 11, 17, 45, 4, 536672), datetime.datetime(2013, 12, 11, 17, 45, 16, 861257), datetime.timedelta(0, 12, 324585)]
# [u'sites.google.com', datetime.datetime(2013, 12, 11, 17, 50, 13, 645286), datetime.datetime(2013, 12, 11, 17, 51, 33, 883506), datetime.timedelta(0, 80, 238220)]

# %%
HTML('<iframe src=viz.html width=700 height=350></iframe>')
# Out:
# <iframe src=viz.html width=700 height=350></iframe>

# %% [markdown]
# # Reference

# %% [raw]
# def getTime(timestamp, pivot="time"):
#     newtime = str(timestamp)
#     stripped1 = newtime.strip(' (),L')
#     ms = int(stripped1)
#     delta = datetime.timedelta(microseconds = ms)
#     epoch_start = datetime.datetime(1601,1,1) + datetime.timedelta(hours = 8)
#     if pivot=="duration":
#         return delta
#     else:
#         return epoch_start + delta

# %% [raw]
# # Query a table
# # def show_table(cu, name="%"):
# #     sql="SELECT * FROM sqlite_master WHERE type='table' and name like '%s';"%(name)
# #     return query(cu, sql)
# # tb = show_table(cu) # return all table
# # tb = show_table(cu, 'urls') # return table with name like urls

# %% [raw]
# def get_transition(transition):
#     code = 0xff
#     transition = code & transition
#
#     flag=""
#     if transition==0:
#         flag = "CLICK_LINK"     ##"LINK: User reached page by clicking a link on another page"
#     elif transition==1:
#         flag = "TYPE_URL"       ##"TYPED: User typed page in URL bar"
#     elif transition==2:
#         flag = "AUTO_BOOKMARK"  ##"AUTO BOOKMARK: User got to this page through a suggestion in the UI"
#     elif transition==3:
#         flag = "AUTO_SUBFRAME"  ##"AUTO SUBFRAME: Content automatically loaded in a non-toplevel frame"
#     elif transition==4:
#         flag = "MANU_SUBFRAME"  ##"MANUAL SUBFRAME: Subframe navigation explicitly requested by the user"
#     elif transition==5:
#         flag = "GENERATED"      ##"GENERATED: User typed page in the URL bar and selected an entry that did not look like a URL"
#     elif transition==6:
#         flag = "START PAGE"     ##"START PAGE: Page was specified in the command line or is the start page"
#     elif transition==7:
#         flag = "FORM SUBMIT"    ##"FORM SUBMIT: User filled out values in a form and submitted it"
#     elif transition==8:
#         flag = "RELOAD"         ##"RELOAD: User reloaded the page"
#     elif transition==9:
#         flag = "KEYWORD"        ##"KEYWORD: URL generated from a replaceable keyword other than the default search provider"
#     elif transition==10:
#         flag = "KEYWORD GENERATED"  ##"KEYWORD GENERATED: Visit was generated by a keyword"
#     else:
#         flag = "UNKNOW"          ##"Unable to understand the transition value. Check, something is horribly wrong here :"
#     return flag

# %% [raw]
# # def top_n_url2(cu, n=None, sql="select url,visit_count from urls order by url ;"):
# #     res = query(cu, sql)
# #     uniq_res = {}
# #     for item in res:
# # #         urlseg = item[0].split('/')
# # #         print urlseg[2]
# #         urlhost = urlparse.urlparse(item[0]).netloc   # for getting host from url
# #         uniq_res.setdefault(urlhost, 0)
# #         uniq_res[urlhost] += item[1]
# #     res_list = uniq_res.items()
# #     res_list.sort(key=lambda x:x[1],reverse=True)
# #     for r in res_list[:10]:
# #         print r
# #     return res_list[:n]
# # res = top_n_url2(cu, 10)

# %% [raw]
# ftable = file("visit_table.html", 'w')
# ftable.write('''<html><body>
# <style>
# td:hover
# {
#    background-color:yellow
# }
# table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
# }
# th, td {
#     padding: 5px;
# }
# th {
#     text-align: left;
# }
# </style>
# <table>
# ''')
# for r in filtered_visits[:20]:
#     ftable.write('''<tr>''')
#     ftable.write('''<td>%s</td>'''%(r[1].strftime('%Y-%m-%d %H:%M:%S')))
#     ftable.write('''<td>%s</td>'''%(r[2].strftime('%Y-%m-%d %H:%M:%S')))
#     ftable.write('''<td>%s</td>'''%(r[3].seconds))
#     ftable.write('''<td>%s</td>'''%(r[0]))
#     ftable.write('''</tr>''')
# ftable.write('''</table></body></html>''')
# ftable.close()
# from IPython.display import HTML
# HTML('<iframe src=visit_table.html width=700 height=350></iframe>')
